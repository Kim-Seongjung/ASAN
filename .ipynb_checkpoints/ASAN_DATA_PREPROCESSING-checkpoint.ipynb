# %%
import os
import numpy as np
import re
from operator import add
import dicom as dc
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from shutil import copyfile

# %%
def sort_by_number(list_):
    
    def atoi(text):
        return int(text) if text.isdigit() else text

    def natural_keys(text):
        return [ atoi(c) for c in re.split('(\d+)', text) ]
    ret_list=list_.sort(key = natural_keys)
    return ret_list

# %%
def get_number_from_list(list_):
    """
    모든 폴더에 있는 파일의 순서를 지정할수 있는 숫자를 얻어낸후 리스트로 리턴한다 
    """
    ret_list=[]
    for i,file_name in enumerate(list_):
        ret_list.append(get_number(file_name))
    ret_list=map(int ,ret_list)
    return ret_list
def get_number(file_name):
    """
    1.3.12.2.1107.5.1.4.51914.30000006121806122618700000702.dcm
    -->30000006121806122618700000702.dcm
    -->name[-4:]=0702
    """
    extension=file_name.split('.')[-1]
    name=file_name.split('.')[-2]
    name=name[-4:]
    """
    """
    return name
def make_dict(list_name , list_path):
    """
    key:02 value:1.3.12.2.1107.5.1.4.51914.30000006121806122618700000702.dcm
    """
    ret_dic={}
    for i,ele in enumerate(list_path):
        ret_dic[list_name[i]]=ele
    return ret_dic
def attach_(arg1 , arg2):
    """
    arg1=elsement_wise 로 붙일 것
    arg2=list
    /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/001/roimask_0013.dcm'
    """
    list_=[]
    for i in range(len(arg2)):        
        list_.append(arg1)
    list_add=map(add,list_,arg2)    
    return list_add

def find_mask(mask_dic):
    cancer_mask={}
    for i,ele in enumerate(mask_dic.keys()):

        dc_file=dc.read_file(mask_dic[ele])
        dc_img=dc_file.pixel_array
        np_img=np.asarray(dc_img)
   
        if np.mean(dc_img)>0:
            "마스크에서 종양의 여부를 식별합니다"+str(ele)+"번째에서 종양이 발견되었습니다"
            #print ele
            #print np.mean(np_img)
            cancer_mask[ele]=mask_dic[ele]
    return cancer_mask

# %%
def dicom_pixel(path):
    dc_file=dc.read_file(path)
    dc_img=dc_file.pixel_array
    return dc_img

# %%
def mask_locate(target_mask):
    locate_mask={}
    print "target_mask.keys():{}".format(target_mask.keys())
    for i,key in enumerate(target_mask.keys()):
        try:
            np_img=dicom_pixel(target_mask[key])
            row,col=np.shape(np_img)
            top_flag=False
            buttom_flag=False
            left_flag=False
            right_flag=False
            for r in range(row):
                if np.mean(np_img[r,:])>0 and top_flag==False:
                    #print r
                    top_line=np_img[r,:]>0
                    for i,ele in enumerate(top_line):
                        if ele==True:
                            top= (r,i)

                            break;

                    top_flag=True
                if top_flag==True and np.mean(np_img[r,:])==0 and buttom_flag==False:        
                    buttom_line=np_img[r-1,:]>0

                    #print r-1
                    for i,ele in enumerate(buttom_line):
                        if ele==True:
                            buttom= (r-1,i)
                            break;
                    buttom_flag=True
           

            left_flag=False
            right_flag=False
            crop_np_img=np_img[top[0]:buttom[0],:]
            for c in range(col):
                if left_flag == False and np.mean(np_img[top[0]:buttom[0],c])>0:
                    left_line = np_img[top[0]:buttom[0],c]>0
                    for i , ele in enumerate(left_line):
                        if ele==True:
                            #print i
                            left = (top[0]+i,c)
                            #print left
                            break;
                    left_flag=True
                if left_flag == True and right_flag==False and np.mean(np_img[top[0]:buttom[0],c])==0:
                    right_line =np_img[top[0]:buttom[0],c-1]>0
                    #print right_line
                    for i , ele in enumerate(right_line):
                        if ele==True:
                            #print i
                            right = (top[0]+i,c-1)
                            #print right
                            break;

                    right_flag =True
            
            center_row = ( buttom[0]-top[0])/2
            center_col = ( right[1]-left[1])/2
            center= (top[0]+center_row) , (left[1]+center_col)
            #print center
            locate_list=[top,buttom,left,right,center]
            locate_mask[key]=locate_list
        except :
            print "error info "
            print "mask : ",key
            print "mask location:",target_mask[key]
            continue;
        print 'top , buttom',top , buttom
        print 'left , right',left , right
    return locate_mask

# %%
a=[1,2,3]
b=[1,2,3]
attach_(1,a)
# Out:
# [2, 3, 4]

# %%
a=[1,2,3]

# %%
def crop_image(img , center, row,col):
    return img[center[0]-(row/2) : center[0]+(row/2) , center[1]-(col/2): center[1]+(col/2)]

# %%
def draw_rectangle_and_save(x,y,np_img ,save_path):

    # Create figure and axes
    fig,ax = plt.subplots(1)
    # Display the image
    ax.imshow(np_img)
    plt.savefig(save_path+'.jpeg')
    
    # Create a Rectangle patch
    rect = patches.Rectangle((x,y),50,50,fill=True,linewidth=1,edgecolor='r',facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(rect)
    
    plt.savefig(save_path+'_rect.jpeg')
    plt.close(plt.gcf())

# %%
''.isdigit()
# Out:
# False

# %%
def crop_mask_target_images_save(mask_dic, mask_locate ,target_dic,save_path):

    print "이미지를 crop 하고 저장합니다 "
    """center 좌표를 이용해 mask 이미지와 target data의 이미지를 자른다
    mask data path 을 가지고 있는 arg: mask_dic
    center좌표를 가지고 있는 arg : mask_locate
    target data path 을 가지고 있는 arg : target_dic
    
    이미지로 저장하냐 
    numpy 로 저장 
    엔지니어 관점 문제점 파일을 2번 열어야 되서 효율성에서 떨어진다 코드를 수정해야 한다.
    넘피로도 저장을 해야 한다 .
    
    target_dic.keys()이가 항상 오름차순이라고 가정한다. 
    확인 하는 코드를 넣어야 한다.
    """
    for i ,key in enumerate(mask_dic.keys()):
        print 'key',key
        #print 'key type' ,type(key)
        key=int(key)
        mask_path=mask_dic[key]
        target_list=sorted(target_dic.keys())
        target_key=target_list[-key]
        target_key_up=target_list[key-1]
        print 'target_key 시작 위치 :'+str(target_list[0])
        print 'target_key 끝 위치 :'+str(target_list[-1])
        
        print 'target_key:'+str(target_key)
        print 'target_key_up:'+str(target_key_up)
        target_path=target_dic[target_key]
        target_path_up=target_dic[target_key_up]
        print 'target_path',target_path
        mask_img=dicom_pixel(mask_path)
        target_img=dicom_pixel(target_path)
        target_img_up=dicom_pixel(target_path_up)
        
        
        
        center=mask_locate[key][4]
        crop_mask_img=crop_image(mask_img  , center , 100 , 100)
        crop_target_img=crop_image(target_img  , center , 100 , 100)
        crop_target_img_up=crop_image(target_img_up  , center , 100 , 100)
        
        mkdir(save_path,str(target_key))
        
        draw_rec_mask_img=draw_rectangle_and_save(25,25,crop_target_img_up,save_path+'/'+str(target_key)+'/crop_target_up_'+str(target_key_up))
        draw_rec_mask_img=draw_rectangle_and_save(25,25,crop_target_img,save_path+'/'+str(target_key)+'/crop_target_'+str(target_key))
        draw_rec_target_img=draw_rectangle_and_save(25,25,crop_mask_img,save_path+'/'+str(target_key)+'/crop_mask_'+str(key))
        
        draw_rec_target_img=draw_rectangle_and_save(center[1]-25,center[0]-25,target_img_up,save_path+'/'+str(target_key)+'/target_up_'+str(target_key_up))
        draw_rec_target_img=draw_rectangle_and_save(center[1]-25,center[0]-25,target_img,save_path+'/'+str(target_key)+'/target_'+str(target_key))
        draw_rec_target_img=draw_rectangle_and_save(center[1]-25,center[0]-25,mask_img,save_path+'/'+str(target_key)+'/mask_'+str(key))

# %%
def mkdir(path,name=None , secceed_on=True):
    if os.path.isdir(path)==False:
        os.mkdir(path)
    if os.path.isdir(path)==True:
        if name != None and os.path.isdir(path+'/'+name)==False:
            os.mkdir(path+'/'+name)

# %%
#folder_path='/home/seongjung/ASAN_project1/project1/CCM_Data/Benign/'
#save_foler='/home/seongjung/ASAN_DATA/Benign'

folder_path='/home/user01/notebook/ASAN_DATA/Benign/'
save_foler ='/home/user01/notebook/ASAN_DATA/Benign_crop_1/'
folder_list = os.walk(folder_path).next()[1]
folder_list=sorted(folder_list) #오름 차순으로 정리 
for i,ele in enumerate(folder_list):
    try:
        print str(i)+'번째 data입니다.'
        subFolder_path=folder_path+ele
        subFolder_list=os.walk(subFolder_path).next()[1]
        print subFolder_list 
        if 'ROI_MASK' in subFolder_list:
            mask_list=os.walk(subFolder_path+'/ROI_MASK').next()[2] #...CCM_Data/Malignant/001'
            mask_path=attach_(subFolder_path+'/ROI_MASK'+'/',mask_list)
            mask_number=get_number_from_list(mask_list) #roimask_0002-->02
            mask_dic=make_dict(mask_number,mask_path)

            ct_list=os.walk(subFolder_path+'/'+subFolder_list[0]+'/').next()[2]
            ct_path=attach_(subFolder_path+'/'+subFolder_list[0]+'/',ct_list)
            ct_number=get_number_from_list(ct_list) #roimask_0002-->02
            ct_dic=make_dict(ct_number,ct_path)

            #print ct_dic.keys(); print ct_dic.values()
            cancer_mask_dic=find_mask(mask_dic)
            cancer_mask_locate=mask_locate(cancer_mask_dic)
            # cancer_mask_locate :top,buttom,left,right,center
            save_path = save_foler+'/'+ele
            if os.path.isdir(save_path)==True:
                continue;
            crop_mask_target_images_save(cancer_mask_dic, cancer_mask_locate , ct_dic ,save_path)
    except Exception as e:
        print str(e);
        continue;
        
        """
        에러가 뜨는 이유는 확실히다 처음 암 영역이 나온 이후 다시 
        나오기 때문이다. 그 알고리즈을 넣어야 한다 .
        
        """
# Out:
# 0번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12]
# top , buttom (320, 61) (333, 66)
# left , right (324, 58) (325, 71)
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :701
# target_key 끝 위치 :716
# target_key:705
# target_key_up:712
# target_path /home/user01/notebook/ASAN_DATA/Benign/001/3/1.3.12.2.1107.5.1.4.51914.30000006121806122618700000705.dcm
# 1번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[10]
# top , buttom (308, 209) (325, 214)
# left , right (315, 206) (316, 218)
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :267
# target_key 끝 위치 :286
# target_key:277
# target_key_up:276
# target_path /home/user01/notebook/ASAN_DATA/Benign/002/3/1.3.12.2.1107.5.1.4.51914.30000006022707104076500022277.dcm
# 2번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[19]
# error info
# mask :  19
# mask location: /home/user01/notebook/ASAN_DATA/Benign/003/ROI_MASK/roimask_0019.dcm
# 이미지를 crop 하고 저장합니다
# key 19
# target_key 시작 위치 :299
# target_key 끝 위치 :334
# target_key:316
# target_key_up:317
# target_path /home/user01/notebook/ASAN_DATA/Benign/003/3/1.3.12.2.1107.5.1.4.50122.30000006082314543246800053316.dcm
# 19
# 3번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[18]
# top , buttom (224, 353) (242, 336)
# left , right (233, 327) (224, 354)
# 이미지를 crop 하고 저장합니다
# key 18
# target_key 시작 위치 :697
# target_key 끝 위치 :761
# target_key:744
# target_key_up:714
# target_path /home/user01/notebook/ASAN_DATA/Benign/004/3/1.3.12.2.1107.5.1.4.65211.30000011100321164867100030744.dcm
# 4번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32]
# top , buttom (312, 127) (350, 134)
# left , right (334, 121) (324, 154)
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :641
# target_key 끝 위치 :700
# target_key:669
# target_key_up:672
# target_path /home/user01/notebook/ASAN_DATA/Benign/005/3/1.3.12.2.1107.5.1.4.66256.30000013061622140489300015669.dcm
# 5번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[17]
# top , buttom (211, 166) (225, 169)
# left , right (218, 160) (222, 172)
# 이미지를 crop 하고 저장합니다
# key 17
# target_key 시작 위치 :836
# target_key 끝 위치 :900
# target_key:884
# target_key_up:852
# target_path /home/user01/notebook/ASAN_DATA/Benign/006/3/1.3.12.2.1107.5.1.4.66417.30000014050722182071100003884.dcm
# 6번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[39]
# top , buttom (324, 144) (348, 130)
# left , right (334, 120) (340, 145)
# 이미지를 crop 하고 저장합니다
# key 39
# target_key 시작 위치 :731
# target_key 끝 위치 :806
# target_key:768
# target_key_up:769
# target_path /home/user01/notebook/ASAN_DATA/Benign/007/3/1.3.12.2.1107.5.1.4.64716.30000013031917054398400007768.dcm
# 7번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[25]
# top , buttom (147, 108) (181, 112)
# left , right (166, 95) (164, 123)
# 이미지를 crop 하고 저장합니다
# key 25
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:975
# target_key_up:969
# target_path /home/user01/notebook/ASAN_DATA/Benign/008/4/1.3.12.2.1107.5.1.4.66256.30000013032422161612600014975.dcm
# 8번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[30, 31]
# top , buttom (133, 191) (154, 186)
# left , right (141, 178) (142, 200)
# top , buttom (139, 189) (151, 189)
# left , right (142, 182) (141, 196)
# 이미지를 crop 하고 저장합니다
# key 30
# target_key 시작 위치 :338
# target_key 끝 위치 :407
# target_key:378
# target_key_up:367
# target_path /home/user01/notebook/ASAN_DATA/Benign/009/3/1.3.12.2.1107.5.1.4.51914.30000013040506225026500001378.dcm
# key 31
# target_key 시작 위치 :338
# target_key 끝 위치 :407
# target_key:377
# target_key_up:368
# target_path /home/user01/notebook/ASAN_DATA/Benign/009/3/1.3.12.2.1107.5.1.4.51914.30000013040506225026500001377.dcm
# 9번째 data입니다.
# ['9', 'ROI_MASK']
# target_mask.keys():[24, 23]
# top , buttom (339, 155) (360, 148)
# left , right (351, 141) (354, 156)
# top , buttom (349, 150) (363, 149)
# left , right (355, 146) (353, 157)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :516
# target_key 끝 위치 :550
# target_key:527
# target_key_up:539
# target_path /home/user01/notebook/ASAN_DATA/Benign/010/9/1.3.12.2.1107.5.1.4.51698.30000010102122173426500007527.dcm
# key 23
# target_key 시작 위치 :516
# target_key 끝 위치 :550
# target_key:528
# target_key_up:538
# target_path /home/user01/notebook/ASAN_DATA/Benign/010/9/1.3.12.2.1107.5.1.4.51698.30000010102122173426500007528.dcm
# 10번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24, 25, 23]
# top , buttom (330, 172) (360, 159)
# left , right (349, 153) (338, 183)
# top , buttom (332, 170) (356, 177)
# left , right (345, 159) (342, 183)
# top , buttom (341, 162) (362, 169)
# left , right (347, 153) (354, 175)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :255
# target_key 끝 위치 :326
# target_key:303
# target_key_up:278
# target_path /home/user01/notebook/ASAN_DATA/Benign/011/3/1.3.12.2.1107.5.1.4.73145.30000015040621254222100018303.dcm
# key 25
# target_key 시작 위치 :255
# target_key 끝 위치 :326
# target_key:302
# target_key_up:279
# target_path /home/user01/notebook/ASAN_DATA/Benign/011/3/1.3.12.2.1107.5.1.4.73145.30000015040621254222100018302.dcm
# key 23
# target_key 시작 위치 :255
# target_key 끝 위치 :326
# target_key:304
# target_key_up:277
# target_path /home/user01/notebook/ASAN_DATA/Benign/011/3/1.3.12.2.1107.5.1.4.73145.30000015040621254222100018304.dcm
# 11번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[14]
# top , buttom (284, 306) (305, 308)
# left , right (288, 301) (295, 318)
# 이미지를 crop 하고 저장합니다
# key 14
# target_key 시작 위치 :941
# target_key 끝 위치 :958
# target_key:945
# target_key_up:954
# target_path /home/user01/notebook/ASAN_DATA/Benign/012/3/1.3.12.2.1107.5.1.4.50122.30000007090321142978100000945.dcm
# 12번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[17, 18, 19, 20, 21]
# top , buttom (244, 177) (261, 191)
# left , right (244, 177) (258, 193)
# top , buttom (241, 184) (272, 185)
# left , right (253, 172) (256, 205)
# top , buttom (239, 185) (273, 185)
# left , right (253, 168) (262, 210)
# top , buttom (238, 193) (270, 182)
# left , right (251, 167) (256, 209)
# top , buttom (243, 181) (267, 191)
# left , right (248, 166) (257, 210)
# 이미지를 crop 하고 저장합니다
# key 17
# target_key 시작 위치 :322
# target_key 끝 위치 :396
# target_key:380
# target_key_up:338
# target_path /home/user01/notebook/ASAN_DATA/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039380.dcm
# key 18
# target_key 시작 위치 :322
# target_key 끝 위치 :396
# target_key:379
# target_key_up:339
# target_path /home/user01/notebook/ASAN_DATA/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039379.dcm
# key 19
# target_key 시작 위치 :322
# target_key 끝 위치 :396
# target_key:378
# target_key_up:340
# target_path /home/user01/notebook/ASAN_DATA/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039378.dcm
# key 20
# target_key 시작 위치 :322
# target_key 끝 위치 :396
# target_key:377
# target_key_up:341
# target_path /home/user01/notebook/ASAN_DATA/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039377.dcm
# key 21
# target_key 시작 위치 :322
# target_key 끝 위치 :396
# target_key:376
# target_key_up:342
# target_path /home/user01/notebook/ASAN_DATA/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039376.dcm
# 13번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[25, 26]
# top , buttom (217, 89) (229, 89)
# left , right (218, 87) (225, 102)
# top , buttom (216, 94) (230, 90)
# left , right (221, 87) (221, 101)
# 이미지를 crop 하고 저장합니다
# key 25
# target_key 시작 위치 :330
# target_key 끝 위치 :393
# target_key:369
# target_key_up:354
# target_path /home/user01/notebook/ASAN_DATA/Benign/014/3/1.3.12.2.1107.5.1.4.51914.30000011072704295728100013369.dcm
# key 26
# target_key 시작 위치 :330
# target_key 끝 위치 :393
# target_key:368
# target_key_up:355
# target_path /home/user01/notebook/ASAN_DATA/Benign/014/3/1.3.12.2.1107.5.1.4.51914.30000011072704295728100013368.dcm
# 14번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[24, 25, 26, 27, 28]
# top , buttom (258, 374) (289, 369)
# left , right (275, 357) (278, 392)
# top , buttom (256, 369) (291, 369)
# left , right (266, 354) (268, 393)
# top , buttom (254, 366) (290, 372)
# left , right (268, 349) (269, 392)
# top , buttom (255, 364) (287, 375)
# left , right (275, 356) (274, 389)
# top , buttom (262, 366) (278, 371)
# left , right (266, 363) (272, 379)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :304
# target_key 끝 위치 :377
# target_key:354
# target_key_up:327
# target_path /home/user01/notebook/ASAN_DATA/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001354.dcm
# key 25
# target_key 시작 위치 :304
# target_key 끝 위치 :377
# target_key:353
# target_key_up:328
# target_path /home/user01/notebook/ASAN_DATA/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001353.dcm
# key 26
# target_key 시작 위치 :304
# target_key 끝 위치 :377
# target_key:352
# target_key_up:329
# target_path /home/user01/notebook/ASAN_DATA/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001352.dcm
# key 27
# target_key 시작 위치 :304
# target_key 끝 위치 :377
# target_key:351
# target_key_up:330
# target_path /home/user01/notebook/ASAN_DATA/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001351.dcm
# key 28
# target_key 시작 위치 :304
# target_key 끝 위치 :377
# target_key:350
# target_key_up:331
# target_path /home/user01/notebook/ASAN_DATA/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001350.dcm
# 15번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 33, 34, 35]
# top , buttom (348, 316) (388, 318)
# left , right (369, 307) (362, 341)
# top , buttom (348, 325) (394, 320)
# left , right (360, 307) (368, 350)
# top , buttom (351, 324) (386, 319)
# left , right (364, 311) (380, 350)
# top , buttom (351, 324) (385, 334)
# left , right (359, 321) (362, 346)
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :855
# target_key 끝 위치 :924
# target_key:893
# target_key_up:886
# target_path /home/user01/notebook/ASAN_DATA/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006893.dcm
# key 33
# target_key 시작 위치 :855
# target_key 끝 위치 :924
# target_key:892
# target_key_up:887
# target_path /home/user01/notebook/ASAN_DATA/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006892.dcm
# key 34
# target_key 시작 위치 :855
# target_key 끝 위치 :924
# target_key:891
# target_key_up:888
# target_path /home/user01/notebook/ASAN_DATA/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006891.dcm
# key 35
# target_key 시작 위치 :855
# target_key 끝 위치 :924
# target_key:890
# target_key_up:889
# target_path /home/user01/notebook/ASAN_DATA/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006890.dcm
# 16번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[39]
# top , buttom (268, 436) (283, 429)
# left , right (274, 423) (272, 440)
# 이미지를 crop 하고 저장합니다
# key 39
# target_key 시작 위치 :488
# target_key 끝 위치 :548
# target_key:510
# target_key_up:526
# target_path /home/user01/notebook/ASAN_DATA/Benign/017/3/1.3.12.2.1107.5.1.4.51914.30000012050705090423400031510.dcm
# 17번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[20, 21, 22, 23]
# top , buttom (251, 315) (283, 327)
# left , right (251, 315) (264, 343)
# top , buttom (246, 333) (288, 335)
# left , right (258, 314) (285, 353)
# top , buttom (250, 331) (286, 332)
# left , right (261, 313) (257, 349)
# top , buttom (253, 324) (284, 326)
# left , right (264, 313) (262, 341)
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :88
# target_key 끝 위치 :160
# target_key:141
# target_key_up:107
# target_path /home/user01/notebook/ASAN_DATA/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002141.dcm
# key 21
# target_key 시작 위치 :88
# target_key 끝 위치 :160
# target_key:140
# target_key_up:108
# target_path /home/user01/notebook/ASAN_DATA/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002140.dcm
# key 22
# target_key 시작 위치 :88
# target_key 끝 위치 :160
# target_key:139
# target_key_up:109
# target_path /home/user01/notebook/ASAN_DATA/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002139.dcm
# key 23
# target_key 시작 위치 :88
# target_key 끝 위치 :160
# target_key:138
# target_key_up:110
# target_path /home/user01/notebook/ASAN_DATA/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002138.dcm
# 18번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[30, 31]
# top , buttom (246, 413) (269, 417)
# left , right (252, 407) (256, 428)
# top , buttom (245, 411) (268, 418)
# left , right (250, 405) (254, 424)
# 이미지를 crop 하고 저장합니다
# key 30
# target_key 시작 위치 :353
# target_key 끝 위치 :420
# target_key:391
# target_key_up:382
# target_path /home/user01/notebook/ASAN_DATA/Benign/019/3/1.3.12.2.1107.5.1.4.66257.30000015122121143646700029391.dcm
# key 31
# target_key 시작 위치 :353
# target_key 끝 위치 :420
# target_key:390
# target_key_up:383
# target_path /home/user01/notebook/ASAN_DATA/Benign/019/3/1.3.12.2.1107.5.1.4.66257.30000015122121143646700029390.dcm
# 19번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 31]
# top , buttom (139, 146) (156, 146)
# left , right (149, 133) (153, 157)
# top , buttom (139, 142) (152, 143)
# left , right (141, 138) (146, 153)
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :293
# target_key 끝 위치 :365
# target_key:334
# target_key_up:324
# target_path /home/user01/notebook/ASAN_DATA/Benign/020/3/1.3.12.2.1107.5.1.4.73145.30000011120722134846800003334.dcm
# key 31
# target_key 시작 위치 :293
# target_key 끝 위치 :365
# target_key:335
# target_key_up:323
# target_path /home/user01/notebook/ASAN_DATA/Benign/020/3/1.3.12.2.1107.5.1.4.73145.30000011120722134846800003335.dcm
# 20번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[20, 21]
# top , buttom (177, 167) (202, 174)
# left , right (184, 159) (191, 193)
# top , buttom (177, 167) (190, 173)
# left , right (184, 162) (180, 178)
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :151
# target_key 끝 위치 :189
# target_key:170
# target_key_up:170
# target_path /home/user01/notebook/ASAN_DATA/Benign/021/3/1.3.12.2.1107.5.1.4.0.30000010101421384959300016170.dcm
# key 21
# target_key 시작 위치 :151
# target_key 끝 위치 :189
# target_key:169
# target_key_up:171
# target_path /home/user01/notebook/ASAN_DATA/Benign/021/3/1.3.12.2.1107.5.1.4.0.30000010101421384959300016169.dcm
# 21번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[35, 36]
# top , buttom (324, 180) (353, 181)
# left , right (330, 171) (332, 201)
# top , buttom (321, 180) (353, 188)
# left , right (328, 168) (330, 202)
# 이미지를 crop 하고 저장합니다
# key 35
# target_key 시작 위치 :91
# target_key 끝 위치 :160
# target_key:126
# target_key_up:125
# target_path /home/user01/notebook/ASAN_DATA/Benign/022/3/1.3.12.2.1107.5.1.4.51914.30000013022506230898400002126.dcm
# key 36
# target_key 시작 위치 :91
# target_key 끝 위치 :160
# target_key:125
# target_key_up:126
# target_path /home/user01/notebook/ASAN_DATA/Benign/022/3/1.3.12.2.1107.5.1.4.51914.30000013022506230898400002125.dcm
# 22번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[24, 25, 26]
# top , buttom (215, 188) (232, 184)
# left , right (222, 178) (224, 198)
# top , buttom (210, 190) (234, 183)
# left , right (223, 175) (220, 198)
# top , buttom (210, 190) (235, 194)
# left , right (218, 179) (227, 198)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :255
# target_key 끝 위치 :328
# target_key:305
# target_key_up:278
# target_path /home/user01/notebook/ASAN_DATA/Benign/023/4/1.3.12.2.1107.5.1.4.64716.30000011051221311832800031305.dcm
# key 25
# target_key 시작 위치 :255
# target_key 끝 위치 :328
# target_key:304
# target_key_up:279
# target_path /home/user01/notebook/ASAN_DATA/Benign/023/4/1.3.12.2.1107.5.1.4.64716.30000011051221311832800031304.dcm
# key 26
# target_key 시작 위치 :255
# target_key 끝 위치 :328
# target_key:303
# target_key_up:280
# target_path /home/user01/notebook/ASAN_DATA/Benign/023/4/1.3.12.2.1107.5.1.4.64716.30000011051221311832800031303.dcm
# 23번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[28, 29, 30, 31]
# top , buttom (313, 403) (340, 400)
# left , right (335, 389) (331, 417)
# top , buttom (308, 402) (342, 399)
# left , right (334, 379) (329, 420)
# top , buttom (307, 399) (342, 394)
# left , right (325, 380) (324, 419)
# top , buttom (309, 392) (341, 401)
# left , right (321, 384) (330, 416)
# 이미지를 crop 하고 저장합니다
# key 28
# target_key 시작 위치 :11
# target_key 끝 위치 :998
# target_key:496
# target_key_up:421
# target_path /home/user01/notebook/ASAN_DATA/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.2222984199528496.dcm
# key 29
# target_key 시작 위치 :11
# target_key 끝 위치 :998
# target_key:465
# target_key_up:427
# target_path /home/user01/notebook/ASAN_DATA/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22229862319652465.dcm
# key 30
# target_key 시작 위치 :11
# target_key 끝 위치 :998
# target_key:427
# target_key_up:465
# target_path /home/user01/notebook/ASAN_DATA/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22229889529266427.dcm
# key 31
# target_key 시작 위치 :11
# target_key 끝 위치 :998
# target_key:421
# target_key_up:496
# target_path /home/user01/notebook/ASAN_DATA/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22229891222239421.dcm
# 24번째 data입니다.
# ['2', 'ROI_MASK']
# target_mask.keys():[29, 30, 31]
# top , buttom (268, 338) (284, 340)
# left , right (277, 334) (274, 350)
# top , buttom (265, 343) (287, 338)
# left , right (275, 331) (269, 352)
# top , buttom (267, 346) (286, 346)
# left , right (281, 333) (280, 353)
# 이미지를 crop 하고 저장합니다
# key 29
# target_key 시작 위치 :755
# target_key 끝 위치 :824
# target_key:796
# target_key_up:783
# target_path /home/user01/notebook/ASAN_DATA/Benign/025/2/1.3.12.2.1107.5.1.4.50122.30000012040723144257800003796.dcm
# key 30
# target_key 시작 위치 :755
# target_key 끝 위치 :824
# target_key:795
# target_key_up:784
# target_path /home/user01/notebook/ASAN_DATA/Benign/025/2/1.3.12.2.1107.5.1.4.50122.30000012040723144257800003795.dcm
# key 31
# target_key 시작 위치 :755
# target_key 끝 위치 :824
# target_key:794
# target_key_up:785
# target_path /home/user01/notebook/ASAN_DATA/Benign/025/2/1.3.12.2.1107.5.1.4.50122.30000012040723144257800003794.dcm
# 25번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12]
# top , buttom (285, 344) (322, 335)
# left , right (308, 320) (312, 355)
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :949
# target_key 끝 위치 :966
# target_key:955
# target_key_up:960
# target_path /home/user01/notebook/ASAN_DATA/Benign/026/3/1.3.12.2.1107.5.1.4.51698.30000007102106532668700004955.dcm
# 26번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92]
# top , buttom (237, 122) (246, 120)
# left , right (240, 118) (239, 124)
# top , buttom (236, 120) (248, 119)
# left , right (241, 115) (241, 126)
# top , buttom (234, 122) (250, 120)
# left , right (241, 113) (238, 127)
# top , buttom (233, 121) (251, 120)
# left , right (240, 112) (238, 128)
# top , buttom (232, 122) (251, 117)
# left , right (242, 111) (236, 128)
# top , buttom (232, 119) (251, 116)
# left , right (244, 110) (240, 129)
# top , buttom (232, 118) (252, 118)
# left , right (235, 111) (239, 129)
# top , buttom (231, 121) (252, 119)
# left , right (234, 111) (240, 129)
# top , buttom (231, 120) (251, 117)
# left , right (239, 111) (242, 129)
# top , buttom (231, 118) (250, 117)
# left , right (242, 111) (241, 128)
# top , buttom (231, 116) (249, 117)
# left , right (242, 112) (238, 126)
# top , buttom (236, 118) (247, 117)
# left , right (244, 114) (238, 124)
# top , buttom (237, 120) (247, 116)
# left , right (239, 116) (240, 123)
# 이미지를 crop 하고 저장합니다
# key 80
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:856
# target_key_up:895
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020856.dcm
# key 81
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:855
# target_key_up:896
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020855.dcm
# key 82
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:854
# target_key_up:897
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020854.dcm
# key 83
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:853
# target_key_up:898
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020853.dcm
# key 84
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:852
# target_key_up:899
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020852.dcm
# key 85
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:851
# target_key_up:900
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020851.dcm
# key 86
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:850
# target_key_up:901
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020850.dcm
# key 87
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:849
# target_key_up:902
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020849.dcm
# key 88
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:848
# target_key_up:903
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020848.dcm
# key 89
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:847
# target_key_up:904
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020847.dcm
# key 90
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:846
# target_key_up:905
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020846.dcm
# key 91
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:845
# target_key_up:906
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020845.dcm
# key 92
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:844
# target_key_up:907
# target_path /home/user01/notebook/ASAN_DATA/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020844.dcm
# 27번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[9]
# top , buttom (173, 398) (205, 402)
# left , right (187, 387) (184, 421)
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :773
# target_key 끝 위치 :792
# target_key:784
# target_key_up:781
# target_path /home/user01/notebook/ASAN_DATA/Benign/028/3/1.3.12.2.1107.5.1.4.51698.30000006051911062317100002784.dcm
# 28번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[11]
# top , buttom (329, 349) (348, 346)
# left , right (344, 341) (332, 363)
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :48
# target_key 끝 위치 :67
# target_key:57
# target_key_up:58
# target_path /home/user01/notebook/ASAN_DATA/Benign/029/4/1.3.12.2.1107.5.1.4.50122.30000009121223332070300015057.dcm
# 29번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[8]
# top , buttom (195, 414) (217, 402)
# left , right (204, 396) (204, 419)
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :349
# target_key 끝 위치 :364
# target_key:357
# target_key_up:356
# target_path /home/user01/notebook/ASAN_DATA/Benign/030/3/1.3.12.2.1107.5.1.4.51698.30000007010510572973400027357.dcm
# 30번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124]
# top , buttom (314, 172) (340, 172)
# left , right (324, 158) (316, 180)
# top , buttom (315, 167) (343, 172)
# left , right (324, 157) (325, 182)
# top , buttom (315, 163) (345, 171)
# left , right (328, 155) (323, 186)
# top , buttom (313, 167) (344, 171)
# left , right (329, 155) (323, 190)
# top , buttom (311, 170) (341, 172)
# left , right (331, 154) (321, 190)
# top , buttom (312, 165) (341, 168)
# left , right (323, 155) (322, 192)
# top , buttom (311, 166) (346, 168)
# left , right (323, 154) (320, 192)
# top , buttom (309, 168) (342, 170)
# left , right (321, 154) (323, 192)
# top , buttom (308, 166) (343, 165)
# left , right (325, 153) (323, 192)
# top , buttom (308, 167) (342, 172)
# left , right (322, 154) (320, 193)
# top , buttom (312, 164) (343, 170)
# left , right (321, 155) (320, 193)
# top , buttom (311, 165) (343, 170)
# left , right (322, 155) (324, 193)
# top , buttom (313, 164) (342, 167)
# left , right (322, 155) (324, 194)
# top , buttom (313, 166) (342, 168)
# left , right (320, 156) (324, 193)
# top , buttom (311, 168) (341, 172)
# left , right (320, 156) (327, 192)
# top , buttom (309, 166) (344, 178)
# left , right (320, 157) (328, 190)
# top , buttom (315, 167) (340, 167)
# left , right (321, 159) (332, 189)
# top , buttom (315, 172) (341, 173)
# left , right (323, 159) (332, 188)
# top , buttom (311, 170) (340, 174)
# left , right (325, 161) (332, 187)
# top , buttom (317, 170) (338, 171)
# left , right (327, 161) (333, 186)
# 이미지를 crop 하고 저장합니다
# key 105
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:124
# target_key_up:883
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257276584113124.dcm
# key 106
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:119
# target_key_up:893
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257086728266119.dcm
# key 107
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:111
# target_key_up:897
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257428971552111.dcm
# key 108
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:110
# target_key_up:906
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257029328898110.dcm
# key 109
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:106
# target_key_up:910
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257423810253106.dcm
# key 110
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:102
# target_key_up:915
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257143525001102.dcm
# key 111
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:86
# target_key_up:919
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257019119512086.dcm
# key 112
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:79
# target_key_up:922
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257245218322079.dcm
# key 113
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:77
# target_key_up:942
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257235013253077.dcm
# key 114
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:69
# target_key_up:952
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257076548802069.dcm
# key 115
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:64
# target_key_up:960
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257135020961064.dcm
# key 116
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:57
# target_key_up:971
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257224812772057.dcm
# key 117
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:53
# target_key_up:972
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257233311571053.dcm
# key 118
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:49
# target_key_up:973
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257112415264049.dcm
# key 119
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:48
# target_key_up:985
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257219322526048.dcm
# key 120
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:44
# target_key_up:989
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257065920543044.dcm
# key 121
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:27
# target_key_up:991
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257212422462027.dcm
# key 122
# target_key 시작 위치 :15
# target_key 끝 위치 :996
# target_key:15
# target_key_up:996
# target_path /home/user01/notebook/ASAN_DATA/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257229929796015.dcm
# key 123
# list index out of range
# 31번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[8]
# top , buttom (202, 101) (232, 109)
# left , right (210, 97) (209, 116)
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :240
# target_key 끝 위치 :254
# target_key:247
# target_key_up:247
# target_path /home/user01/notebook/ASAN_DATA/Benign/032/3/1.3.12.2.1107.5.1.4.50122.30000009110522100664000030247.dcm
# 32번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[7]
# top , buttom (186, 185) (205, 179)
# left , right (196, 171) (192, 191)
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :771
# target_key 끝 위치 :789
# target_key:783
# target_key_up:777
# target_path /home/user01/notebook/ASAN_DATA/Benign/033/3/1.3.12.2.1107.5.1.4.50122.30000009101122073135900002783.dcm
# 33번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[9]
# top , buttom (254, 358) (273, 360)
# left , right (261, 344) (262, 373)
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :47
# target_key 끝 위치 :63
# target_key:55
# target_key_up:55
# target_path /home/user01/notebook/ASAN_DATA/Benign/034/3/1.3.12.2.1107.5.1.4.50122.30000008040823461129600000055.dcm
# 34번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[18]
# top , buttom (282, 344) (296, 343)
# left , right (286, 338) (285, 355)
# 이미지를 crop 하고 저장합니다
# key 18
# target_key 시작 위치 :20
# target_key 끝 위치 :64
# target_key:47
# target_key_up:37
# target_path /home/user01/notebook/ASAN_DATA/Benign/035/3/1.3.12.2.1107.5.1.4.51914.30000010102207193750000025047.dcm
# 35번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[5]
# top , buttom (300, 319) (328, 313)
# left , right (314, 309) (314, 348)
# 이미지를 crop 하고 저장합니다
# key 5
# target_key 시작 위치 :432
# target_key 끝 위치 :447
# target_key:443
# target_key_up:436
# target_path /home/user01/notebook/ASAN_DATA/Benign/036/3/1.3.12.2.1107.5.1.4.51914.30000009072305130043700012443.dcm
# 36번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[10]
# top , buttom (243, 143) (274, 146)
# left , right (256, 130) (264, 168)
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :399
# target_key 끝 위치 :416
# target_key:407
# target_key_up:408
# target_path /home/user01/notebook/ASAN_DATA/Benign/037/3/1.3.12.2.1107.5.1.4.51914.30000006090505233182800006407.dcm
# 37번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[9]
# top , buttom (284, 411) (300, 412)
# left , right (290, 408) (292, 421)
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :825
# target_key 끝 위치 :844
# target_key:836
# target_key_up:833
# target_path /home/user01/notebook/ASAN_DATA/Benign/038/3/1.3.12.2.1107.5.1.4.50122.30000009110922103810900006836.dcm
# 38번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[14]
# top , buttom (254, 183) (279, 188)
# left , right (272, 170) (271, 195)
# 이미지를 crop 하고 저장합니다
# key 14
# target_key 시작 위치 :606
# target_key 끝 위치 :625
# target_key:612
# target_key_up:619
# target_path /home/user01/notebook/ASAN_DATA/Benign/039/3/1.3.12.2.1107.5.1.4.51698.30000006092705203528100017612.dcm
# 39번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[11]
# top , buttom (254, 129) (270, 124)
# left , right (260, 120) (261, 139)
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :89
# target_key 끝 위치 :105
# target_key:95
# target_key_up:99
# target_path /home/user01/notebook/ASAN_DATA/Benign/040/3/1.3.12.2.1107.5.1.4.51698.30000009062822064573400004095.dcm
# 40번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[8]
# top , buttom (261, 355) (298, 352)
# left , right (272, 341) (279, 377)
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :2
# target_key 끝 위치 :19
# target_key:12
# target_key_up:9
# target_path /home/user01/notebook/ASAN_DATA/Benign/041/3/1.3.12.2.1107.5.1.4.51914.30000006100905202520300000012.dcm
# 41번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[9]
# top , buttom (163, 377) (197, 384)
# left , right (177, 371) (184, 401)
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :365
# target_key 끝 위치 :380
# target_key:372
# target_key_up:373
# target_path /home/user01/notebook/ASAN_DATA/Benign/042/3/1.3.12.2.1107.5.1.4.50122.30000007012522161959300022372.dcm
# 42번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[31]
# top , buttom (293, 418) (312, 417)
# left , right (300, 410) (300, 426)
# 이미지를 crop 하고 저장합니다
# key 31
# target_key 시작 위치 :624
# target_key 끝 위치 :683
# target_key:653
# target_key_up:654
# target_path /home/user01/notebook/ASAN_DATA/Benign/043/3/1.3.12.2.1107.5.1.4.83202.30000015081423382901200016653.dcm
# 43번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[9]
# top , buttom (318, 155) (337, 158)
# left , right (323, 151) (328, 172)
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :469
# target_key 끝 위치 :487
# target_key:479
# target_key_up:477
# target_path /home/user01/notebook/ASAN_DATA/Benign/044/3/1.3.12.2.1107.5.1.4.51914.30000007052805201420300019479.dcm
# 44번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[10, 7]
# top , buttom (160, 151) (197, 167)
# left , right (176, 144) (170, 180)
# top , buttom (235, 363) (245, 371)
# left , right (238, 361) (237, 374)
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :667
# target_key 끝 위치 :681
# target_key:672
# target_key_up:676
# target_path /home/user01/notebook/ASAN_DATA/Benign/045/4/1.3.12.2.1107.5.1.4.51698.30000008122922075679600023672.dcm
# key 7
# target_key 시작 위치 :667
# target_key 끝 위치 :681
# target_key:675
# target_key_up:673
# target_path /home/user01/notebook/ASAN_DATA/Benign/045/4/1.3.12.2.1107.5.1.4.51698.30000008122922075679600023675.dcm
# 45번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12]
# top , buttom (256, 324) (283, 317)
# left , right (267, 309) (265, 337)
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :783
# target_key 끝 위치 :801
# target_key:790
# target_key_up:794
# target_path /home/user01/notebook/ASAN_DATA/Benign/046/3/1.3.12.2.1107.5.1.4.51914.30000008061604381298400032790.dcm
# 46번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[44, 45, 46, 47]
# top , buttom (273, 177) (291, 182)
# left , right (278, 174) (281, 192)
# top , buttom (269, 174) (291, 175)
# left , right (275, 167) (280, 194)
# top , buttom (269, 186) (292, 175)
# left , right (279, 167) (281, 194)
# top , buttom (278, 178) (292, 175)
# left , right (290, 172) (280, 191)
# 이미지를 crop 하고 저장합니다
# key 44
# target_key 시작 위치 :367
# target_key 끝 위치 :439
# target_key:396
# target_key_up:410
# target_path /home/user01/notebook/ASAN_DATA/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006396.dcm
# key 45
# target_key 시작 위치 :367
# target_key 끝 위치 :439
# target_key:395
# target_key_up:411
# target_path /home/user01/notebook/ASAN_DATA/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006395.dcm
# key 46
# target_key 시작 위치 :367
# target_key 끝 위치 :439
# target_key:394
# target_key_up:412
# target_path /home/user01/notebook/ASAN_DATA/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006394.dcm
# key 47
# target_key 시작 위치 :367
# target_key 끝 위치 :439
# target_key:393
# target_key_up:413
# target_path /home/user01/notebook/ASAN_DATA/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006393.dcm
# 47번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[8]
# top , buttom (200, 142) (230, 133)
# left , right (209, 122) (222, 157)
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :781
# target_key 끝 위치 :797
# target_key:790
# target_key_up:788
# target_path /home/user01/notebook/ASAN_DATA/Benign/048/3/1.3.12.2.1107.5.1.4.50122.30000008101221295062500001790.dcm
# 48번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[7]
# top , buttom (297, 333) (340, 345)
# left , right (318, 308) (325, 353)
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :661
# target_key 끝 위치 :678
# target_key:672
# target_key_up:667
# target_path /home/user01/notebook/ASAN_DATA/Benign/049/3/1.3.12.2.1107.5.1.4.51914.30000008091604134812500030672.dcm
# 49번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[26]
# top , buttom (273, 421) (289, 424)
# left , right (280, 416) (276, 430)
# 이미지를 crop 하고 저장합니다
# key 26
# target_key 시작 위치 :211
# target_key 끝 위치 :268
# target_key:243
# target_key_up:236
# target_path /home/user01/notebook/ASAN_DATA/Benign/050/3/1.3.12.2.1107.5.1.4.66256.30000015011521244105600034243.dcm
# 50번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[10]
# top , buttom (296, 126) (319, 124)
# left , right (304, 115) (305, 137)
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :757
# target_key 끝 위치 :773
# target_key:764
# target_key_up:766
# target_path /home/user01/notebook/ASAN_DATA/Benign/051/3/1.3.12.2.1107.5.1.4.50122.30000009112922021559300037764.dcm
# 51번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[11]
# top , buttom (124, 186) (139, 186)
# left , right (130, 181) (134, 194)
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :627
# target_key 끝 위치 :655
# target_key:645
# target_key_up:637
# target_path /home/user01/notebook/ASAN_DATA/Benign/052/3/1.3.12.2.1107.5.1.4.50122.30000010053021170260900002645.dcm
# 52번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[9]
# top , buttom (260, 370) (282, 373)
# left , right (272, 365) (275, 393)
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :452
# target_key 끝 위치 :467
# target_key:459
# target_key_up:460
# target_path /home/user01/notebook/ASAN_DATA/Benign/053/3/1.3.12.2.1107.5.1.4.51914.30000010011707360689000000459.dcm
# 53번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[42, 43]
# top , buttom (273, 396) (295, 399)
# left , right (277, 390) (288, 411)
# top , buttom (271, 396) (298, 400)
# left , right (282, 390) (279, 411)
# 이미지를 crop 하고 저장합니다
# key 42
# target_key 시작 위치 :850
# target_key 끝 위치 :916
# target_key:875
# target_key_up:891
# target_path /home/user01/notebook/ASAN_DATA/Benign/054/3/1.3.12.2.1107.5.1.4.66257.30000015040821453883800014875.dcm
# key 43
# target_key 시작 위치 :850
# target_key 끝 위치 :916
# target_key:874
# target_key_up:892
# target_path /home/user01/notebook/ASAN_DATA/Benign/054/3/1.3.12.2.1107.5.1.4.66257.30000015040821453883800014874.dcm
# 54번째 data입니다.
# ['6', 'ROI_MASK']
# target_mask.keys():[34]
# top , buttom (328, 95) (356, 100)
# left , right (336, 85) (336, 110)
# 이미지를 crop 하고 저장합니다
# key 34
# target_key 시작 위치 :451
# target_key 끝 위치 :527
# target_key:494
# target_key_up:484
# target_path /home/user01/notebook/ASAN_DATA/Benign/055/6/1.3.12.2.1107.5.1.4.65211.30000012031221233120300032494.dcm
# 55번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[7]
# top , buttom (196, 197) (237, 192)
# left , right (218, 177) (202, 217)
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :140
# target_key 끝 위치 :156
# target_key:150
# target_key_up:146
# target_path /home/user01/notebook/ASAN_DATA/Benign/056/3/1.3.12.2.1107.5.1.4.51914.30000010042704154726500035150.dcm
# 56번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[20]
# top , buttom (291, 155) (312, 159)
# left , right (298, 146) (303, 169)
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :585
# target_key 끝 위치 :617
# target_key:598
# target_key_up:604
# target_path /home/user01/notebook/ASAN_DATA/Benign/057/3/1.3.12.2.1107.5.1.4.51698.30000010092822071225000042598.dcm
# 57번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[7]
# top , buttom (312, 333) (336, 329)
# left , right (318, 320) (326, 343)
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :158
# target_key 끝 위치 :184
# target_key:178
# target_key_up:164
# target_path /home/user01/notebook/ASAN_DATA/Benign/058/3/1.3.12.2.1107.5.1.4.50122.30000010072021132912500004178.dcm
# 58번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[48, 49, 50]
# top , buttom (284, 200) (303, 201)
# left , right (293, 192) (299, 213)
# top , buttom (284, 200) (310, 201)
# left , right (293, 191) (297, 211)
# top , buttom (289, 200) (304, 208)
# left , right (295, 195) (302, 210)
# 이미지를 crop 하고 저장합니다
# key 48
# target_key 시작 위치 :636
# target_key 끝 위치 :708
# target_key:661
# target_key_up:683
# target_path /home/user01/notebook/ASAN_DATA/Benign/059/3/1.3.12.2.1107.5.1.4.50122.30000013022422082659300019661.dcm
# key 49
# target_key 시작 위치 :636
# target_key 끝 위치 :708
# target_key:660
# target_key_up:684
# target_path /home/user01/notebook/ASAN_DATA/Benign/059/3/1.3.12.2.1107.5.1.4.50122.30000013022422082659300019660.dcm
# key 50
# target_key 시작 위치 :636
# target_key 끝 위치 :708
# target_key:659
# target_key_up:685
# target_path /home/user01/notebook/ASAN_DATA/Benign/059/3/1.3.12.2.1107.5.1.4.50122.30000013022422082659300019659.dcm
# 59번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[10, 11]
# top , buttom (217, 219) (254, 207)
# left , right (230, 198) (233, 235)
# top , buttom (217, 221) (252, 217)
# left , right (240, 202) (231, 236)
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :71
# target_key 끝 위치 :107
# target_key:98
# target_key_up:80
# target_path /home/user01/notebook/ASAN_DATA/Benign/060/3/1.3.12.2.1107.5.1.4.51914.30000010101105153268700010098.dcm
# key 11
# target_key 시작 위치 :71
# target_key 끝 위치 :107
# target_key:97
# target_key_up:81
# target_path /home/user01/notebook/ASAN_DATA/Benign/060/3/1.3.12.2.1107.5.1.4.51914.30000010101105153268700010097.dcm
# 60번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[54, 55]
# top , buttom (342, 383) (358, 385)
# left , right (349, 378) (346, 393)
# top , buttom (342, 384) (359, 388)
# left , right (348, 377) (347, 394)
# 이미지를 crop 하고 저장합니다
# key 54
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:18
# target_key_up:981
# target_path /home/user01/notebook/ASAN_DATA/Benign/061/4/1.3.12.2.1107.5.1.4.65211.30000011063021185384300019018.dcm
# key 55
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:17
# target_key_up:982
# target_path /home/user01/notebook/ASAN_DATA/Benign/061/4/1.3.12.2.1107.5.1.4.65211.30000011063021185384300019017.dcm
# 61번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[40, 41, 42, 39]
# top , buttom (327, 335) (359, 331)
# left , right (351, 325) (340, 344)
# top , buttom (324, 334) (361, 336)
# left , right (350, 319) (335, 346)
# top , buttom (326, 334) (354, 327)
# left , right (340, 318) (342, 342)
# top , buttom (335, 336) (354, 331)
# left , right (347, 331) (346, 344)
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :599
# target_key 끝 위치 :657
# target_key:618
# target_key_up:638
# target_path /home/user01/notebook/ASAN_DATA/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002618.dcm
# key 41
# target_key 시작 위치 :599
# target_key 끝 위치 :657
# target_key:617
# target_key_up:639
# target_path /home/user01/notebook/ASAN_DATA/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002617.dcm
# key 42
# target_key 시작 위치 :599
# target_key 끝 위치 :657
# target_key:616
# target_key_up:640
# target_path /home/user01/notebook/ASAN_DATA/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002616.dcm
# key 39
# target_key 시작 위치 :599
# target_key 끝 위치 :657
# target_key:619
# target_key_up:637
# target_path /home/user01/notebook/ASAN_DATA/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002619.dcm
# 62번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24, 23]
# top , buttom (277, 383) (295, 384)
# left , right (284, 376) (287, 398)
# top , buttom (276, 389) (294, 386)
# left , right (285, 378) (282, 395)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :631
# target_key 끝 위치 :700
# target_key:677
# target_key_up:654
# target_path /home/user01/notebook/ASAN_DATA/Benign/063/3/1.3.12.2.1107.5.1.4.65211.30000011050221132051500005677.dcm
# key 23
# target_key 시작 위치 :631
# target_key 끝 위치 :700
# target_key:678
# target_key_up:653
# target_path /home/user01/notebook/ASAN_DATA/Benign/063/3/1.3.12.2.1107.5.1.4.65211.30000011050221132051500005678.dcm
# 63번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[21]
# top , buttom (260, 61) (282, 68)
# left , right (265, 57) (273, 78)
# 이미지를 crop 하고 저장합니다
# key 21
# target_key 시작 위치 :282
# target_key 끝 위치 :332
# target_key:312
# target_key_up:302
# target_path /home/user01/notebook/ASAN_DATA/Benign/064/3/1.3.12.2.1107.5.1.4.50122.30000011053021272156200022312.dcm
# 64번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[40]
# top , buttom (306, 334) (322, 331)
# left , right (313, 326) (313, 345)
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :712
# target_key 끝 위치 :773
# target_key:734
# target_key_up:751
# target_path /home/user01/notebook/ASAN_DATA/Benign/065/3/1.3.12.2.1107.5.1.4.65211.30000011071421155470300014734.dcm
# 65번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[43, 44, 45]
# top , buttom (319, 170) (334, 166)
# left , right (323, 163) (325, 181)
# top , buttom (310, 167) (340, 184)
# left , right (320, 156) (323, 185)
# top , buttom (310, 174) (333, 167)
# left , right (324, 159) (323, 184)
# 이미지를 crop 하고 저장합니다
# key 43
# target_key 시작 위치 :81
# target_key 끝 위치 :143
# target_key:101
# target_key_up:123
# target_path /home/user01/notebook/ASAN_DATA/Benign/066/3/1.3.12.2.1107.5.1.4.51914.30000012020605104837500031101.dcm
# key 44
# target_key 시작 위치 :81
# target_key 끝 위치 :143
# target_key:100
# target_key_up:124
# target_path /home/user01/notebook/ASAN_DATA/Benign/066/3/1.3.12.2.1107.5.1.4.51914.30000012020605104837500031100.dcm
# key 45
# target_key 시작 위치 :81
# target_key 끝 위치 :143
# target_key:99
# target_key_up:125
# target_path /home/user01/notebook/ASAN_DATA/Benign/066/3/1.3.12.2.1107.5.1.4.51914.30000012020605104837500031099.dcm
# 66번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[21, 22]
# top , buttom (236, 386) (246, 389)
# left , right (239, 381) (238, 395)
# top , buttom (232, 383) (248, 384)
# left , right (242, 378) (236, 394)
# 이미지를 crop 하고 저장합니다
# key 21
# target_key 시작 위치 :78
# target_key 끝 위치 :131
# target_key:111
# target_key_up:98
# target_path /home/user01/notebook/ASAN_DATA/Benign/067/3/1.3.12.2.1107.5.1.4.50122.30000012041222092062500036111.dcm
# key 22
# target_key 시작 위치 :78
# target_key 끝 위치 :131
# target_key:110
# target_key_up:99
# target_path /home/user01/notebook/ASAN_DATA/Benign/067/3/1.3.12.2.1107.5.1.4.50122.30000012041222092062500036110.dcm
# 67번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12, 13]
# top , buttom (270, 234) (288, 231)
# left , right (276, 225) (280, 241)
# top , buttom (273, 229) (286, 231)
# left , right (273, 229) (284, 242)
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :764
# target_key 끝 위치 :828
# target_key:817
# target_key_up:775
# target_path /home/user01/notebook/ASAN_DATA/Benign/068/3/1.3.12.2.1107.5.1.4.50122.30000012013120573207800013817.dcm
# key 13
# target_key 시작 위치 :764
# target_key 끝 위치 :828
# target_key:816
# target_key_up:776
# target_path /home/user01/notebook/ASAN_DATA/Benign/068/3/1.3.12.2.1107.5.1.4.50122.30000012013120573207800013816.dcm
# 68번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[42, 43, 44, 45]
# top , buttom (256, 161) (268, 161)
# left , right (263, 157) (259, 170)
# top , buttom (251, 160) (273, 161)
# left , right (256, 151) (261, 173)
# top , buttom (250, 159) (272, 157)
# left , right (257, 150) (257, 174)
# top , buttom (252, 161) (267, 157)
# left , right (258, 152) (256, 173)
# 이미지를 crop 하고 저장합니다
# key 42
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:958
# target_key_up:976
# target_path /home/user01/notebook/ASAN_DATA/Benign/069/4/1.3.12.2.1107.5.1.4.51914.30000012101004142942100035958.dcm
# key 43
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:957
# target_key_up:977
# target_path /home/user01/notebook/ASAN_DATA/Benign/069/4/1.3.12.2.1107.5.1.4.51914.30000012101004142942100035957.dcm
# key 44
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:956
# target_key_up:978
# target_path /home/user01/notebook/ASAN_DATA/Benign/069/4/1.3.12.2.1107.5.1.4.51914.30000012101004142942100035956.dcm
# key 45
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:955
# target_key_up:979
# target_path /home/user01/notebook/ASAN_DATA/Benign/069/4/1.3.12.2.1107.5.1.4.51914.30000012101004142942100035955.dcm
# 69번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[28, 29]
# top , buttom (350, 150) (361, 148)
# left , right (355, 146) (352, 160)
# top , buttom (348, 148) (363, 149)
# left , right (352, 146) (353, 162)
# 이미지를 crop 하고 저장합니다
# key 28
# target_key 시작 위치 :134
# target_key 끝 위치 :197
# target_key:170
# target_key_up:161
# target_path /home/user01/notebook/ASAN_DATA/Benign/070/3/1.3.12.2.1107.5.1.4.51914.30000012032805145489000035170.dcm
# key 29
# target_key 시작 위치 :134
# target_key 끝 위치 :197
# target_key:169
# target_key_up:162
# target_path /home/user01/notebook/ASAN_DATA/Benign/070/3/1.3.12.2.1107.5.1.4.51914.30000012032805145489000035169.dcm
# 70번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[19, 20]
# top , buttom (198, 385) (214, 386)
# left , right (203, 383) (205, 399)
# top , buttom (201, 388) (213, 387)
# left , right (204, 385) (203, 397)
# 이미지를 crop 하고 저장합니다
# key 19
# target_key 시작 위치 :139
# target_key 끝 위치 :202
# target_key:184
# target_key_up:157
# target_path /home/user01/notebook/ASAN_DATA/Benign/071/3/1.3.12.2.1107.5.1.4.51698.30000015020421260956200010184.dcm
# key 20
# target_key 시작 위치 :139
# target_key 끝 위치 :202
# target_key:183
# target_key_up:158
# target_path /home/user01/notebook/ASAN_DATA/Benign/071/3/1.3.12.2.1107.5.1.4.51698.30000015020421260956200010183.dcm
# 71번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[34, 35]
# top , buttom (179, 144) (205, 149)
# left , right (189, 134) (188, 157)
# top , buttom (179, 142) (203, 143)
# left , right (190, 133) (197, 160)
# 이미지를 crop 하고 저장합니다
# key 34
# target_key 시작 위치 :411
# target_key 끝 위치 :475
# target_key:442
# target_key_up:444
# target_path /home/user01/notebook/ASAN_DATA/Benign/072/3/1.3.12.2.1107.5.1.4.73145.30000012030821410304600031442.dcm
# key 35
# target_key 시작 위치 :411
# target_key 끝 위치 :475
# target_key:441
# target_key_up:445
# target_path /home/user01/notebook/ASAN_DATA/Benign/072/3/1.3.12.2.1107.5.1.4.73145.30000012030821410304600031441.dcm
# 72번째 data입니다.
# ['8', 'ROI_MASK']
# target_mask.keys():[36, 37, 38, 39]
# top , buttom (223, 66) (244, 70)
# left , right (226, 64) (229, 87)
# top , buttom (221, 68) (249, 71)
# left , right (226, 63) (233, 90)
# top , buttom (220, 72) (251, 69)
# left , right (226, 62) (231, 88)
# top , buttom (226, 69) (246, 69)
# left , right (229, 64) (232, 86)
# 이미지를 crop 하고 저장합니다
# key 36
# target_key 시작 위치 :534
# target_key 끝 위치 :611
# target_key:576
# target_key_up:569
# target_path /home/user01/notebook/ASAN_DATA/Benign/073/8/1.3.12.2.1107.5.1.4.64716.30000012062420470007800039576.dcm
# key 37
# target_key 시작 위치 :534
# target_key 끝 위치 :611
# target_key:575
# target_key_up:570
# ...
# target_path /home/user01/notebook/ASAN_DATA/Benign/075/3/1.3.12.2.1107.5.1.4.83202.30000014072921374579000021030.dcm
# key 30
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:32
# target_key_up:29
# target_path /home/user01/notebook/ASAN_DATA/Benign/075/3/1.3.12.2.1107.5.1.4.83202.30000014072921374579000021032.dcm
# key 31
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:31
# target_key_up:30
# target_path /home/user01/notebook/ASAN_DATA/Benign/075/3/1.3.12.2.1107.5.1.4.83202.30000014072921374579000021031.dcm
# 75번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[20, 21, 22, 23]
# top , buttom (283, 87) (301, 81)
# left , right (290, 81) (291, 92)
# top , buttom (276, 85) (301, 80)
# left , right (285, 79) (288, 100)
# top , buttom (273, 92) (298, 85)
# left , right (282, 78) (277, 102)
# top , buttom (277, 88) (291, 88)
# left , right (280, 82) (281, 100)
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :123
# target_key 끝 위치 :194
# target_key:175
# target_key_up:142
# target_path /home/user01/notebook/ASAN_DATA/Benign/076/3/1.3.12.2.1107.5.1.4.51698.30000012051021305104600024175.dcm
# key 21
# target_key 시작 위치 :123
# target_key 끝 위치 :194
# target_key:174
# target_key_up:143
# target_path /home/user01/notebook/ASAN_DATA/Benign/076/3/1.3.12.2.1107.5.1.4.51698.30000012051021305104600024174.dcm
# key 22
# target_key 시작 위치 :123
# target_key 끝 위치 :194
# target_key:173
# target_key_up:144
# target_path /home/user01/notebook/ASAN_DATA/Benign/076/3/1.3.12.2.1107.5.1.4.51698.30000012051021305104600024173.dcm
# key 23
# target_key 시작 위치 :123
# target_key 끝 위치 :194
# target_key:172
# target_key_up:145
# target_path /home/user01/notebook/ASAN_DATA/Benign/076/3/1.3.12.2.1107.5.1.4.51698.30000012051021305104600024172.dcm
# 76번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 33, 31]
# top , buttom (306, 368) (324, 375)
# left , right (315, 366) (312, 388)
# top , buttom (306, 380) (324, 376)
# left , right (314, 369) (307, 385)
# top , buttom (304, 383) (317, 368)
# left , right (316, 367) (308, 385)
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :229
# target_key 끝 위치 :285
# target_key:254
# target_key_up:260
# target_path /home/user01/notebook/ASAN_DATA/Benign/077/3/1.3.12.2.1107.5.1.4.66256.30000014102121292412000045254.dcm
# key 33
# target_key 시작 위치 :229
# target_key 끝 위치 :285
# target_key:253
# target_key_up:261
# target_path /home/user01/notebook/ASAN_DATA/Benign/077/3/1.3.12.2.1107.5.1.4.66256.30000014102121292412000045253.dcm
# key 31
# target_key 시작 위치 :229
# target_key 끝 위치 :285
# target_key:255
# target_key_up:259
# target_path /home/user01/notebook/ASAN_DATA/Benign/077/3/1.3.12.2.1107.5.1.4.66256.30000014102121292412000045255.dcm
# 77번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 33, 34]
# top , buttom (239, 144) (248, 141)
# left , right (242, 139) (244, 148)
# top , buttom (234, 142) (255, 144)
# left , right (238, 131) (244, 153)
# top , buttom (235, 141) (255, 141)
# left , right (243, 133) (242, 152)
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :815
# target_key 끝 위치 :886
# target_key:855
# target_key_up:846
# target_path /home/user01/notebook/ASAN_DATA/Benign/078/3/1.3.12.2.1107.5.1.4.65211.30000012061121143587500015855.dcm
# key 33
# target_key 시작 위치 :815
# target_key 끝 위치 :886
# target_key:854
# target_key_up:847
# target_path /home/user01/notebook/ASAN_DATA/Benign/078/3/1.3.12.2.1107.5.1.4.65211.30000012061121143587500015854.dcm
# key 34
# target_key 시작 위치 :815
# target_key 끝 위치 :886
# target_key:853
# target_key_up:848
# target_path /home/user01/notebook/ASAN_DATA/Benign/078/3/1.3.12.2.1107.5.1.4.65211.30000012061121143587500015853.dcm
# 78번째 data입니다.
# ['9', 'ROI_MASK']
# target_mask.keys():[16]
# top , buttom (301, 345) (311, 344)
# left , right (306, 340) (305, 354)
# 이미지를 crop 하고 저장합니다
# key 16
# target_key 시작 위치 :457
# target_key 끝 위치 :532
# target_key:517
# target_key_up:472
# target_path /home/user01/notebook/ASAN_DATA/Benign/079/9/1.3.12.2.1107.5.1.4.65211.30000012091921111318700027517.dcm
# 79번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[37, 38, 39]
# top , buttom (384, 335) (400, 329)
# left , right (392, 326) (387, 341)
# top , buttom (379, 340) (405, 333)
# left , right (392, 326) (384, 347)
# top , buttom (379, 338) (405, 336)
# left , right (386, 326) (386, 348)
# 이미지를 crop 하고 저장합니다
# key 37
# target_key 시작 위치 :179
# target_key 끝 위치 :245
# target_key:209
# target_key_up:215
# target_path /home/user01/notebook/ASAN_DATA/Benign/080/3/1.3.12.2.1107.5.1.4.65211.30000012110722022178100030209.dcm
# key 38
# target_key 시작 위치 :179
# target_key 끝 위치 :245
# target_key:208
# target_key_up:216
# target_path /home/user01/notebook/ASAN_DATA/Benign/080/3/1.3.12.2.1107.5.1.4.65211.30000012110722022178100030208.dcm
# key 39
# target_key 시작 위치 :179
# target_key 끝 위치 :245
# target_key:207
# target_key_up:217
# target_path /home/user01/notebook/ASAN_DATA/Benign/080/3/1.3.12.2.1107.5.1.4.65211.30000012110722022178100030207.dcm
# 80번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[24, 23]
# top , buttom (200, 140) (216, 144)
# left , right (206, 138) (205, 152)
# top , buttom (203, 147) (215, 146)
# left , right (209, 142) (208, 151)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :524
# target_key 끝 위치 :583
# target_key:560
# target_key_up:547
# target_path /home/user01/notebook/ASAN_DATA/Benign/081/4/1.3.12.2.1107.5.1.4.66257.30000013021102264440300005560.dcm
# key 23
# target_key 시작 위치 :524
# target_key 끝 위치 :583
# target_key:561
# target_key_up:546
# target_path /home/user01/notebook/ASAN_DATA/Benign/081/4/1.3.12.2.1107.5.1.4.66257.30000013021102264440300005561.dcm
# 81번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[17, 18, 19]
# top , buttom (303, 348) (319, 354)
# left , right (308, 339) (312, 359)
# top , buttom (297, 356) (318, 347)
# left , right (310, 335) (308, 363)
# top , buttom (298, 355) (317, 350)
# left , right (307, 344) (301, 361)
# 이미지를 crop 하고 저장합니다
# key 17
# target_key 시작 위치 :560
# target_key 끝 위치 :633
# target_key:617
# target_key_up:576
# target_path /home/user01/notebook/ASAN_DATA/Benign/082/4/1.3.12.2.1107.5.1.4.83099.30000016042421305736400031617.dcm
# key 18
# target_key 시작 위치 :560
# target_key 끝 위치 :633
# target_key:616
# target_key_up:577
# target_path /home/user01/notebook/ASAN_DATA/Benign/082/4/1.3.12.2.1107.5.1.4.83099.30000016042421305736400031616.dcm
# key 19
# target_key 시작 위치 :560
# target_key 끝 위치 :633
# target_key:615
# target_key_up:578
# target_path /home/user01/notebook/ASAN_DATA/Benign/082/4/1.3.12.2.1107.5.1.4.83099.30000016042421305736400031615.dcm
# 82번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[43, 44]
# top , buttom (235, 88) (258, 89)
# left , right (249, 78) (242, 97)
# top , buttom (234, 88) (256, 88)
# left , right (243, 81) (244, 97)
# 이미지를 crop 하고 저장합니다
# key 43
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:679
# target_key_up:694
# target_path /home/user01/notebook/ASAN_DATA/Benign/083/3/1.3.12.2.1107.5.1.4.50122.30000013060900205596800000679.dcm
# key 44
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:678
# target_key_up:695
# target_path /home/user01/notebook/ASAN_DATA/Benign/083/3/1.3.12.2.1107.5.1.4.50122.30000013060900205596800000678.dcm
# 83번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[42, 43, 44]
# top , buttom (343, 157) (362, 149)
# left , right (350, 141) (357, 169)
# top , buttom (342, 157) (366, 161)
# left , right (351, 143) (356, 170)
# top , buttom (335, 160) (365, 158)
# left , right (352, 147) (349, 168)
# 이미지를 crop 하고 저장합니다
# key 42
# target_key 시작 위치 :216
# target_key 끝 위치 :283
# target_key:242
# target_key_up:257
# target_path /home/user01/notebook/ASAN_DATA/Benign/084/3/1.3.12.2.1107.5.1.4.66417.30000013101322192712900024242.dcm
# key 43
# target_key 시작 위치 :216
# target_key 끝 위치 :283
# target_key:241
# target_key_up:258
# target_path /home/user01/notebook/ASAN_DATA/Benign/084/3/1.3.12.2.1107.5.1.4.66417.30000013101322192712900024241.dcm
# key 44
# target_key 시작 위치 :216
# target_key 끝 위치 :283
# target_key:240
# target_key_up:259
# target_path /home/user01/notebook/ASAN_DATA/Benign/084/3/1.3.12.2.1107.5.1.4.66417.30000013101322192712900024240.dcm
# 84번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[40, 41, 42, 38, 39]
# top , buttom (192, 195) (224, 190)
# left , right (204, 181) (200, 206)
# top , buttom (193, 197) (220, 192)
# left , right (208, 180) (197, 205)
# top , buttom (197, 195) (213, 192)
# left , right (200, 190) (203, 204)
# top , buttom (198, 192) (222, 196)
# left , right (206, 184) (205, 208)
# top , buttom (195, 190) (225, 192)
# left , right (203, 181) (202, 209)
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :29
# target_key 끝 위치 :93
# target_key:54
# target_key_up:68
# target_path /home/user01/notebook/ASAN_DATA/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029054.dcm
# key 41
# target_key 시작 위치 :29
# target_key 끝 위치 :93
# target_key:53
# target_key_up:69
# target_path /home/user01/notebook/ASAN_DATA/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029053.dcm
# key 42
# target_key 시작 위치 :29
# target_key 끝 위치 :93
# target_key:52
# target_key_up:70
# target_path /home/user01/notebook/ASAN_DATA/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029052.dcm
# key 38
# target_key 시작 위치 :29
# target_key 끝 위치 :93
# target_key:56
# target_key_up:66
# target_path /home/user01/notebook/ASAN_DATA/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029056.dcm
# key 39
# target_key 시작 위치 :29
# target_key 끝 위치 :93
# target_key:55
# target_key_up:67
# target_path /home/user01/notebook/ASAN_DATA/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029055.dcm
# 85번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24, 25, 26]
# top , buttom (199, 168) (217, 173)
# left , right (205, 164) (203, 178)
# top , buttom (197, 167) (227, 169)
# left , right (206, 160) (204, 179)
# top , buttom (196, 176) (214, 171)
# left , right (208, 163) (204, 181)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:976
# target_key_up:23
# target_path /home/user01/notebook/ASAN_DATA/Benign/086/3/1.3.12.2.1107.5.1.4.66417.30000015102521065461500035976.dcm
# key 25
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:975
# target_key_up:24
# target_path /home/user01/notebook/ASAN_DATA/Benign/086/3/1.3.12.2.1107.5.1.4.66417.30000015102521065461500035975.dcm
# key 26
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:974
# target_key_up:25
# target_path /home/user01/notebook/ASAN_DATA/Benign/086/3/1.3.12.2.1107.5.1.4.66417.30000015102521065461500035974.dcm
# 86번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[48, 47]
# top , buttom (339, 374) (347, 378)
# left , right (340, 373) (343, 382)
# top , buttom (335, 375) (350, 376)
# left , right (339, 369) (342, 385)
# 이미지를 crop 하고 저장합니다
# key 48
# target_key 시작 위치 :880
# target_key 끝 위치 :945
# target_key:898
# target_key_up:927
# target_path /home/user01/notebook/ASAN_DATA/Benign/087/3/1.3.12.2.1107.5.1.4.66417.30000014102321231623200031898.dcm
# key 47
# target_key 시작 위치 :880
# target_key 끝 위치 :945
# target_key:899
# target_key_up:926
# target_path /home/user01/notebook/ASAN_DATA/Benign/087/3/1.3.12.2.1107.5.1.4.66417.30000014102321231623200031899.dcm
# 87번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[33, 34]
# top , buttom (332, 204) (342, 203)
# left , right (336, 199) (336, 208)
# top , buttom (329, 202) (349, 201)
# left , right (335, 196) (339, 214)
# 이미지를 crop 하고 저장합니다
# key 33
# target_key 시작 위치 :151
# target_key 끝 위치 :215
# target_key:183
# target_key_up:183
# target_path /home/user01/notebook/ASAN_DATA/Benign/088/3/1.3.12.2.1107.5.1.4.83099.30000014102821363771800041183.dcm
# key 34
# target_key 시작 위치 :151
# target_key 끝 위치 :215
# target_key:182
# target_key_up:184
# target_path /home/user01/notebook/ASAN_DATA/Benign/088/3/1.3.12.2.1107.5.1.4.83099.30000014102821363771800041182.dcm
# 88번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[33, 34]
# top , buttom (335, 394) (352, 394)
# left , right (340, 388) (345, 408)
# top , buttom (332, 390) (350, 392)
# left , right (340, 384) (340, 408)
# 이미지를 crop 하고 저장합니다
# key 33
# target_key 시작 위치 :64
# target_key 끝 위치 :127
# target_key:95
# target_key_up:96
# target_path /home/user01/notebook/ASAN_DATA/Benign/089/4/1.3.12.2.1107.5.1.4.51698.30000015010121153334300000095.dcm
# key 34
# target_key 시작 위치 :64
# target_key 끝 위치 :127
# target_key:94
# target_key_up:97
# target_path /home/user01/notebook/ASAN_DATA/Benign/089/4/1.3.12.2.1107.5.1.4.51698.30000015010121153334300000094.dcm
# 89번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 33, 34, 35, 31]
# top , buttom (179, 382) (208, 388)
# left , right (192, 371) (188, 396)
# top , buttom (183, 381) (206, 383)
# left , right (190, 370) (191, 396)
# top , buttom (183, 378) (202, 383)
# left , right (188, 375) (188, 400)
# top , buttom (185, 382) (201, 391)
# left , right (190, 378) (192, 394)
# top , buttom (180, 385) (205, 393)
# left , right (189, 374) (187, 396)
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :455
# target_key 끝 위치 :525
# target_key:494
# target_key_up:486
# target_path /home/user01/notebook/ASAN_DATA/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025494.dcm
# key 33
# target_key 시작 위치 :455
# target_key 끝 위치 :525
# target_key:493
# target_key_up:487
# target_path /home/user01/notebook/ASAN_DATA/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025493.dcm
# key 34
# target_key 시작 위치 :455
# target_key 끝 위치 :525
# target_key:492
# target_key_up:488
# target_path /home/user01/notebook/ASAN_DATA/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025492.dcm
# key 35
# target_key 시작 위치 :455
# target_key 끝 위치 :525
# target_key:491
# target_key_up:489
# target_path /home/user01/notebook/ASAN_DATA/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025491.dcm
# key 31
# target_key 시작 위치 :455
# target_key 끝 위치 :525
# target_key:495
# target_key_up:485
# target_path /home/user01/notebook/ASAN_DATA/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025495.dcm
# 90번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[26, 27, 28]
# top , buttom (270, 102) (295, 102)
# left , right (279, 87) (289, 111)
# top , buttom (270, 102) (297, 105)
# left , right (283, 84) (286, 112)
# top , buttom (280, 97) (293, 100)
# left , right (282, 94) (285, 106)
# 이미지를 crop 하고 저장합니다
# key 26
# target_key 시작 위치 :675
# target_key 끝 위치 :754
# target_key:729
# target_key_up:700
# target_path /home/user01/notebook/ASAN_DATA/Benign/091/3/1.3.12.2.1107.5.1.4.66417.30000015051721350206700003729.dcm
# key 27
# target_key 시작 위치 :675
# target_key 끝 위치 :754
# target_key:728
# target_key_up:701
# target_path /home/user01/notebook/ASAN_DATA/Benign/091/3/1.3.12.2.1107.5.1.4.66417.30000015051721350206700003728.dcm
# key 28
# target_key 시작 위치 :675
# target_key 끝 위치 :754
# target_key:727
# target_key_up:702
# target_path /home/user01/notebook/ASAN_DATA/Benign/091/3/1.3.12.2.1107.5.1.4.66417.30000015051721350206700003727.dcm
# 91번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[16, 15]
# top , buttom (187, 202) (207, 196)
# left , right (196, 190) (194, 209)
# top , buttom (186, 196) (209, 199)
# left , right (195, 189) (193, 211)
# 이미지를 crop 하고 저장합니다
# key 16
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:61
# target_key_up:15
# target_path /home/user01/notebook/ASAN_DATA/Benign/092/3/1.3.12.2.1107.5.1.4.51698.30000015091223460512500009061.dcm
# key 15
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:62
# target_key_up:14
# target_path /home/user01/notebook/ASAN_DATA/Benign/092/3/1.3.12.2.1107.5.1.4.51698.30000015091223460512500009062.dcm
# 92번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[40, 41, 38, 39]
# top , buttom (305, 207) (331, 209)
# left , right (314, 197) (311, 222)
# top , buttom (305, 206) (332, 212)
# left , right (313, 199) (318, 220)
# top , buttom (304, 210) (335, 213)
# left , right (321, 202) (312, 225)
# top , buttom (302, 208) (335, 213)
# left , right (317, 199) (312, 226)
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :143
# target_key 끝 위치 :213
# target_key:174
# target_key_up:182
# target_path /home/user01/notebook/ASAN_DATA/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009174.dcm
# key 41
# target_key 시작 위치 :143
# target_key 끝 위치 :213
# target_key:173
# target_key_up:183
# target_path /home/user01/notebook/ASAN_DATA/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009173.dcm
# key 38
# target_key 시작 위치 :143
# target_key 끝 위치 :213
# target_key:176
# target_key_up:180
# target_path /home/user01/notebook/ASAN_DATA/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009176.dcm
# key 39
# target_key 시작 위치 :143
# target_key 끝 위치 :213
# target_key:175
# target_key_up:181
# target_path /home/user01/notebook/ASAN_DATA/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009175.dcm

# %%
#folder_path='/home/seongjung/ASAN_project1/project1/CCM_Data/Benign/'
#save_foler='/home/seongjung/ASAN_DATA/Benign'

folder_path='/home/user01/notebook/ASAN_DATA/Malignant/'
save_foler ='/home/user01/notebook/ASAN_DATA/Malignant_crop/'
folder_list = os.walk(folder_path).next()[1]
folder_list=sorted(folder_list) #오름 차순으로 정리 
for i,ele in enumerate(folder_list):
    try:
        print str(i)+'번째 data입니다.'
        subFolder_path=folder_path+ele
        subFolder_list=os.walk(subFolder_path).next()[1]
        print subFolder_list 
        if 'ROI_MASK' in subFolder_list:
            mask_list=os.walk(subFolder_path+'/ROI_MASK').next()[2] #...CCM_Data/Malignant/001'
            mask_path=attach_(subFolder_path+'/ROI_MASK'+'/',mask_list)
            mask_number=get_number_from_list(mask_list) #roimask_0002-->02
            mask_dic=make_dict(mask_number,mask_path)

            ct_list=os.walk(subFolder_path+'/'+subFolder_list[0]+'/').next()[2]
            ct_path=attach_(subFolder_path+'/'+subFolder_list[0]+'/',ct_list)
            ct_number=get_number_from_list(ct_list) #roimask_0002-->02
            ct_dic=make_dict(ct_number,ct_path)

            #print ct_dic.keys(); print ct_dic.values()
            cancer_mask_dic=find_mask(mask_dic)
            cancer_mask_locate=mask_locate(cancer_mask_dic)
            # cancer_mask_locate :top,buttom,left,right,center
            save_path = save_foler+'/'+ele
            if os.path.isdir(save_path)==True:
                continue;
            crop_mask_target_images_save(cancer_mask_dic, cancer_mask_locate , ct_dic ,save_path)
    except Exception as e:
        print str(e);
        continue;
        
        """
        에러가 뜨는 이유는 확실히다 처음 암 영역이 나온 이후 다시 
        나오기 때문이다. 그 알고리즈을 넣어야 한다 .
        
        """
# Out:
# 0번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[44]
# top , buttom (216, 130) (233, 131)
# left , right (220, 123) (220, 138)
# 1번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[27, 28]
# top , buttom (247, 139) (287, 123)
# left , right (272, 114) (267, 153)
# top , buttom (241, 137) (279, 128)
# left , right (265, 112) (256, 147)
# 2번째 data입니다.
# ['8', 'ROI_MASK']
# target_mask.keys():
째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[17, 18]
# top , buttom (322, 174) (365, 179)
# left , right (350, 171) (335, 200)
# top , buttom (321, 183) (357, 190)
# left , right (341, 167) (328, 201)
# 135번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[19, 20, 21]
# top , buttom (278, 111) (297, 109)
# left , right (287, 98) (283, 120)
# top , buttom (275, 105) (299, 104)
# left , right (280, 96) (287, 121)
# top , buttom (277, 107) (290, 104)
# left , right (282, 99) (280, 112)
# 136번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[48, 49, 47]
# top , buttom (364, 374) (386, 370)
# left , right (372, 358) (378, 379)
# top , buttom (367, 367) (383, 361)
# left , right (375, 357) (374, 372)
# top , buttom (367, 362) (383, 372)
# left , right (371, 357) (376, 376)
# 137번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[9, 10]
# top , buttom (255, 131) (281, 131)
# left , right (261, 114) (279, 153)
# top , buttom (259, 127) (267, 117)
# left , right (265, 116) (262, 143)
# 138번째 data입니다.
# ['8', 'ROI_MASK']
# target_mask.keys():[18]
# top , buttom (348, 137) (365, 134)
# left , right (358, 120) (357, 146)
# 139번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[17]
# top , buttom (309, 373) (335, 371)
# left , right (324, 358) (319, 385)
# 140번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24, 25, 26]
# top , buttom (257, 406) (277, 403)
# left , right (267, 396) (264, 431)
# top , buttom (248, 411) (281, 408)
# left , right (262, 392) (268, 435)
# top , buttom (257, 400) (281, 410)
# left , right (262, 396) (269, 430)
# 141번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[18, 19, 20]
# top , buttom (189, 399) (200, 391)
# left , right (196, 388) (189, 401)
# top , buttom (173, 397) (203, 373)
# left , right (202, 373) (191, 402)
# top , buttom (168, 393) (192, 380)
# left , right (182, 378) (172, 397)
# 142번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24, 25, 26]
# top , buttom (337, 112) (364, 112)
# left , right (352, 99) (349, 117)
# top , buttom (323, 115) (366, 119)
# left , right (346, 95) (350, 133)
# top , buttom (332, 113) (361, 111)
# left , right (351, 97) (344, 125)
# 143번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12]
# top , buttom (361, 371) (376, 369)
# left , right (362, 366) (367, 381)
# 144번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 33, 30, 31]
# top , buttom (289, 352) (319, 356)
# left , right (294, 331) (311, 375)
# top , buttom (291, 355) (307, 356)
# left , right (296, 346) (299, 360)
# top , buttom (299, 351) (307, 355)
# left , right (302, 348) (303, 364)
# top , buttom (293, 350) (320, 360)
# left , right (311, 343) (298, 372)
# 145번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12, 13]
# top , buttom (303, 125) (333, 115)
# left , right (309, 105) (321, 143)
# top , buttom (303, 126) (330, 121)
# left , right (326, 110) (313, 138)
# 146번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[34, 35, 36]
# top , buttom (297, 309) (311, 303)
# left , right (302, 303) (302, 315)
# top , buttom (290, 303) (312, 311)
# left , right (300, 298) (300, 320)
# top , buttom (292, 313) (313, 311)
# left , right (301, 300) (301, 323)
# 147번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[18]
# top , buttom (231, 414) (246, 409)
# left , right (240, 406) (237, 422)
# 148번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[28, 29, 30]
# top , buttom (197, 427) (221, 426)
# left , right (209, 417) (212, 441)
# top , buttom (202, 431) (210, 423)
# left , right (209, 423) (205, 438)
# top , buttom (204, 444) (212, 435)
# left , right (207, 427) (204, 444)
# 149번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[34, 
째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[44, 45]
# top , buttom (351, 163) (367, 168)
# left , right (355, 158) (359, 172)
# top , buttom (349, 161) (366, 164)
# left , right (358, 159) (359, 173)
# 169번째 data입니다.
# ['4', 'ROI_MASK']
# target_mask.keys():[43, 44, 45, 46]
# top , buttom (351, 390) (359, 394)
# left , right (351, 390) (356, 401)
# top , buttom (344, 387) (364, 379)
# left , right (357, 374) (354, 410)
# top , buttom (342, 389) (368, 393)
# left , right (354, 380) (353, 409)
# top , buttom (347, 387) (366, 397)
# left , right (356, 381) (355, 404)
# 170번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[15, 16, 17, 18, 19, 20, 21, 22]
# top , buttom (312, 191) (327, 196)
# left , right (316, 187) (317, 212)
# top , buttom (311, 196) (324, 201)
# left , right (313, 190) (316, 209)
# top , buttom (308, 196) (329, 196)
# left , right (312, 192) (315, 208)
# top , buttom (308, 202) (323, 199)
# left , right (311, 190) (312, 208)
# top , buttom (299, 199) (325, 190)
# left , right (310, 183) (309, 208)
# top , buttom (300, 196) (324, 199)
# left , right (318, 182) (314, 219)
# top , buttom (296, 193) (322, 185)
# left , right (311, 180) (305, 204)
# top , buttom (301, 201) (325, 187)
# left , right (309, 184) (302, 202)
# 171번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[32, 33, 34]
# top , buttom (376, 125) (386, 132)
# left , right (378, 122) (378, 122)
# top , buttom (373, 130) (388, 134)
# left , right (380, 121) (384, 139)
# top , buttom (372, 131) (388, 129)
# left , right (380, 122) (382, 139)
# 172번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[48, 49, 50]
# top , buttom (367, 338) (378, 342)
# left , right (369, 337) (376, 348)
# top , buttom (363, 340) (379, 351)
# left , right (368, 330) (369, 351)
# top , buttom (364, 346) (381, 346)
# left , right (375, 341) (373, 353)
# 173번째 data입니다.
# ['8', 'ROI_MASK']
# target_mask.keys():[34, 35, 36]
# top , buttom (295, 105) (309, 97)
# left , right (303, 86) (296, 111)
# top , buttom (294, 91) (318, 90)
# left , right (304, 81) (298, 109)
# top , buttom (293, 97) (307, 95)
# left , right (299, 78) (300, 107)
# 174번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[17, 18, 19, 20]
# top , buttom (309, 105) (314, 109)
# left , right (309, 105) (312, 110)
# top , buttom (298, 105) (317, 100)
# left , right (303, 93) (309, 122)
# top , buttom (292, 102) (320, 104)
# left , right (306, 96) (317, 123)
# top , buttom (301, 102) (320, 106)
# left , right (305, 99) (306, 112)
# 175번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[38, 39]
# top , buttom (348, 131) (363, 129)
# left , right (356, 121) (351, 135)
# top , buttom (344, 127) (362, 120)
# left , right (354, 118) (351, 138)
# 176번째 data입니다.
# ['8', 'ROI_MASK']
# target_mask.keys():[32]
# top , buttom (234, 132) (261, 137)
# left , right (240, 126) (247, 150)
# 177번째 data입니다.
# ['3', 'ROI_MASK']
# ...
# left , right (135, 224) (124, 246)
# 318번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[40, 41, 42, 43]
# top , buttom (353, 303) (362, 303)
# left , right (360, 297) (355, 307)
# top , buttom (347, 306) (366, 311)
# left , right (356, 298) (357, 315)
# top , buttom (347, 307) (365, 302)
# left , right (356, 298) (356, 318)
# top , buttom (359, 306) (364, 304)
# left , right (361, 301) (361, 314)
# 319번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[28, 29, 30, 31]
# top , buttom (349, 161) (380, 154)
# left , right (371, 148) (358, 175)
# top , buttom (344, 164) (374, 162)
# left , right (365, 135) (359, 179)
# top , buttom (350, 171) (374, 164)
# left , right (355, 139) (362, 183)
# top , buttom (349, 166) (367, 160)
# left , right (359, 154) (353, 174)
# 320번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24,
째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[42, 43, 44, 45, 46]
# top , buttom (352, 333) (381, 344)
# left , right (359, 329) (360, 357)
# top , buttom (352, 346) (380, 343)
# left , right (365, 328) (360, 364)
# top , buttom (353, 352) (375, 340)
# left , right (362, 331) (356, 363)
# top , buttom (349, 335) (374, 341)
# left , right (351, 334) (357, 363)
# top , buttom (352, 344) (369, 341)
# left , right (358, 336) (356, 356)
# 334번째 data입니다.
# ['8', 'ROI_MASK']
# target_mask.keys():[33, 34, 35]
# top , buttom (145, 199) (176, 197)
# left , right (152, 194) (161, 218)
# top , buttom (143, 206) (160, 211)
# left , right (151, 198) (158, 220)
# top , buttom (136, 204) (143, 204)
# left , right (136, 204) (136, 215)
# 이미지를 crop 하고 저장합니다
# key 33
# target_key 시작 위치 :603
# target_key 끝 위치 :671
# target_key:639
# target_key_up:635
# target_path /home/user01/notebook/ASAN_DATA/Malignant/335/8/1.3.12.2.1107.5.1.4.73145.30000015061021315062800072639.dcm
# key 34
# target_key 시작 위치 :603
# target_key 끝 위치 :671
# target_key:638
# target_key_up:636
# target_path /home/user01/notebook/ASAN_DATA/Malignant/335/8/1.3.12.2.1107.5.1.4.73145.30000015061021315062800072638.dcm
# key 35
# target_key 시작 위치 :603
# target_key 끝 위치 :671
# target_key:637
# target_key_up:637
# target_path /home/user01/notebook/ASAN_DATA/Malignant/335/8/1.3.12.2.1107.5.1.4.73145.30000015061021315062800072637.dcm
# 335번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[22]
# top , buttom (350, 153) (368, 153)
# left , right (356, 150) (360, 166)
# 이미지를 crop 하고 저장합니다
# key 22
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:978
# target_key_up:21
# target_path /home/user01/notebook/ASAN_DATA/Malignant/336/3/1.3.12.2.1107.5.1.4.83099.30000015052721362749700008978.dcm
# 336번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[34, 35, 36, 37, 38, 39]
# top , buttom (389, 146) (412, 164)
# left , right (395, 135) (409, 172)
# top , buttom (381, 150) (412, 155)
# left , right (404, 132) (400, 166)
# top , buttom (379, 160) (409, 143)
# left , right (397, 124) (404, 161)
# top , buttom (371, 149) (410, 146)
# left , right (401, 118) (387, 160)
# top , buttom (363, 138) (405, 126)
# left , right (390, 118) (368, 141)
# top , buttom (384, 126) (408, 124)
# left , right (398, 115) (394, 132)
# 이미지를 crop 하고 저장합니다
# key 34
# target_key 시작 위치 :643
# target_key 끝 위치 :707
# target_key:674
# target_key_up:676
# target_path /home/user01/notebook/ASAN_DATA/Malignant/337/3/1.3.12.2.1107.5.1.4.66417.30000015070621224072400036674.dcm
# key 35
# target_key 시작 위치 :643
# target_key 끝 위치 :707
# target_key:673
# target_key_up:677
# target_path /home/user01/notebook/ASAN_DATA/Malignant/337/3/1.3.12.2.1107.5.1.4.66417.30000015070621224072400036673.dcm
# key 36
# target_key 시작 위치 :643
# target_key 끝 위치 :707
# target_key:672
# target_key_up:678
# target_path /home/user01/notebook/ASAN_DATA/Malignant/337/3/1.3.12.2.1107.5.1.4.66417.30000015070621224072400036672.dcm
# key 37
# target_key 시작 위치 :643
# target_key 끝 위치 :707
# target_key:671
# target_key_up:679
# target_path /home/user01/notebook/ASAN_DATA/Malignant/337/3/1.3.12.2.1107.5.1.4.66417.30000015070621224072400036671.dcm
# key 38
# target_key 시작 위치 :643
# target_key 끝 위치 :707
# target_key:670
# target_key_up:680
# target_path /home/user01/notebook/ASAN_DATA/Malignant/337/3/1.3.12.2.1107.5.1.4.66417.30000015070621224072400036670.dcm
# key 39
# target_key 시작 위치 :643
# target_key 끝 위치 :707
# target_key:669
# target_key_up:681
# target_path /home/user01/notebook/ASAN_DATA/Malignant/337/3/1.3.12.2.1107.5.1.4.66417.30000015070621224072400036669.dcm
# 337번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[27, 28]
# top , buttom (235, 385) (254, 380)
# left , right (242, 378) (238, 392)
# top , buttom (232, 388) (258, 381)
# left , right (247, 370) (244, 390)
# 이미지를 crop 하고 저장합니다
# key 27
# target_key 시작 위치 :618
# target_key 끝 위치 :699
# target_key:673
# target_key_up:644
# target_path /home/user01/notebook/ASAN_DATA/Malignant/338/3/1.3.12.2.1107.5.1.4.66417.30000015120523541508000017673.dcm
# key 28
# target_key 시작 위치 :618
# target_key 끝 위치 :699
# target_key:672
# target_key_up:645
# target_path /home/user01/notebook/ASAN_DATA/Malignant/338/3/1.3.12.2.1107.5.1.4.66417.30000015120523541508000017672.dcm
# 338번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[18, 19, 20]
# top , buttom (318, 119) (345, 129)
# left , right (331, 114) (340, 135)
# top , buttom (321, 127) (342, 117)
# left , right (326, 101) (332, 135)
# top , buttom (317, 124) (335, 119)
# left , right (327, 109) (320, 136)
# 이미지를 crop 하고 저장합니다
# key 18
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:704
# target_key_up:669
# target_path /home/user01/notebook/ASAN_DATA/Malignant/339/3/1.3.12.2.1107.5.1.4.66256.30000015062921224685200021704.dcm
# key 19
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:703
# target_key_up:670
# target_path /home/user01/notebook/ASAN_DATA/Malignant/339/3/1.3.12.2.1107.5.1.4.66256.30000015062921224685200021703.dcm
# key 20
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:702
# target_key_up:671
# target_path /home/user01/notebook/ASAN_DATA/Malignant/339/3/1.3.12.2.1107.5.1.4.66256.30000015062921224685200021702.dcm
# 339번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[26, 27]
# top , buttom (252, 117) (283, 121)
# left , right (257, 102) (262, 132)
# top , buttom (248, 116) (276, 114)
# left , right (259, 104) (264, 129)
# 이미지를 crop 하고 저장합니다
# key 26
# target_key 시작 위치 :64
# target_key 끝 위치 :128
# target_key:103
# target_key_up:89
# target_path /home/user01/notebook/ASAN_DATA/Malignant/340/3/1.3.12.2.1107.5.1.4.83202.30000015063021291463500036103.dcm
# key 27
# target_key 시작 위치 :64
# target_key 끝 위치 :128
# target_key:102
# target_key_up:90
# target_path /home/user01/notebook/ASAN_DATA/Malignant/340/3/1.3.12.2.1107.5.1.4.83202.30000015063021291463500036102.dcm
# 340번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[18, 19]
# top , buttom (179, 168) (205, 159)
# left , right (191, 152) (192, 153)
# top , buttom (173, 210) (212, 184)
# left , right (205, 157) (180, 222)
# 이미지를 crop 하고 저장합니다
# key 18
# target_key 시작 위치 :169
# target_key 끝 위치 :228
# target_key:211
# target_key_up:186
# target_path /home/user01/notebook/ASAN_DATA/Malignant/341/3/1.3.12.2.1107.5.1.4.83202.30000015071221175740300040211.dcm
# key 19
# target_key 시작 위치 :169
# target_key 끝 위치 :228
# target_key:210
# target_key_up:187
# target_path /home/user01/notebook/ASAN_DATA/Malignant/341/3/1.3.12.2.1107.5.1.4.83202.30000015071221175740300040210.dcm
# 341번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[11, 12, 13, 14]
# top , buttom (264, 332) (280, 326)
# left , right (272, 319) (267, 336)
# top , buttom (258, 314) (293, 313)
# left , right (272, 309) (263, 332)
# top , buttom (251, 314) (285, 313)
# left , right (272, 307) (270, 332)
# top , buttom (261, 319) (284, 327)
# left , right (265, 311) (275, 333)
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :835
# target_key 끝 위치 :901
# target_key:891
# target_key_up:845
# target_path /home/user01/notebook/ASAN_DATA/Malignant/342/3/1.3.12.2.1107.5.1.4.51698.30000015081523461446800010891.dcm
# key 12
# target_key 시작 위치 :835
# target_key 끝 위치 :901
# target_key:890
# target_key_up:846
# target_path /home/user01/notebook/ASAN_DATA/Malignant/342/3/1.3.12.2.1107.5.1.4.51698.30000015081523461446800010890.dcm
# key 13
# target_key 시작 위치 :835
# target_key 끝 위치 :901
# target_key:889
# target_key_up:847
# target_path /home/user01/notebook/ASAN_DATA/Malignant/342/3/1.3.12.2.1107.5.1.4.51698.30000015081523461446800010889.dcm
# key 14
# target_key 시작 위치 :835
# target_key 끝 위치 :901
# target_key:888
# target_key_up:848
# target_path /home/user01/notebook/ASAN_DATA/Malignant/342/3/1.3.12.2.1107.5.1.4.51698.30000015081523461446800010888.dcm
# 342번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[12, 13, 14, 15]
# top , buttom (312, 328) (330, 315)
# left , right (325, 309) (314, 329)
# top , buttom (302, 314) (328, 310)
# left , right (310, 299) (311, 340)
# top , buttom (297, 321) (327, 313)
# left , right (309, 303) (310, 332)
# top , buttom (303, 311) (327, 308)
# left , right (313, 301) (316, 328)
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :67
# target_key 끝 위치 :131
# target_key:120
# target_key_up:78
# target_path /home/user01/notebook/ASAN_DATA/Malignant/343/3/1.3.12.2.1107.5.1.4.73145.30000015092021315397300000120.dcm
# key 13
# target_key 시작 위치 :67
# target_key 끝 위치 :131
# target_key:119
# target_key_up:79
# target_path /home/user01/notebook/ASAN_DATA/Malignant/343/3/1.3.12.2.1107.5.1.4.73145.30000015092021315397300000119.dcm
# key 14
# target_key 시작 위치 :67
# target_key 끝 위치 :131
# target_key:118
# target_key_up:80
# target_path /home/user01/notebook/ASAN_DATA/Malignant/343/3/1.3.12.2.1107.5.1.4.73145.30000015092021315397300000118.dcm
# key 15
# target_key 시작 위치 :67
# target_key 끝 위치 :131
# target_key:117
# target_key_up:81
# target_path /home/user01/notebook/ASAN_DATA/Malignant/343/3/1.3.12.2.1107.5.1.4.73145.30000015092021315397300000117.dcm
# 343번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[24, 23]
# top , buttom (218, 100) (244, 89)
# left , right (240, 89) (223, 105)
# top , buttom (222, 99) (222, 99)
# left , right (240, 89) (223, 105)
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :624
# target_key 끝 위치 :687
# target_key:664
# target_key_up:647
# target_path /home/user01/notebook/ASAN_DATA/Malignant/344/3/1.3.12.2.1107.5.1.4.83202.30000015101821243641100030664.dcm
# key 23
# target_key 시작 위치 :624
# target_key 끝 위치 :687
# target_key:665
# target_key_up:646
# target_path /home/user01/notebook/ASAN_DATA/Malignant/344/3/1.3.12.2.1107.5.1.4.83202.30000015101821243641100030665.dcm
# 344번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[36, 37, 38]
# top , buttom (198, 120) (210, 125)
# left , right (200, 116) (202, 132)
# top , buttom (187, 123) (215, 126)
# left , right (198, 117) (208, 142)
# top , buttom (180, 121) (220, 121)
# left , right (202, 112) (205, 140)
# 이미지를 crop 하고 저장합니다
# key 36
# target_key 시작 위치 :846
# target_key 끝 위치 :922
# target_key:887
# target_key_up:881
# target_path /home/user01/notebook/ASAN_DATA/Malignant/345/3/1.3.12.2.1107.5.1.4.66257.30000015092921284760300000887.dcm
# key 37
# target_key 시작 위치 :846
# target_key 끝 위치 :922
# target_key:886
# target_key_up:882
# target_path /home/user01/notebook/ASAN_DATA/Malignant/345/3/1.3.12.2.1107.5.1.4.66257.30000015092921284760300000886.dcm
# key 38
# target_key 시작 위치 :846
# target_key 끝 위치 :922
# target_key:885
# target_key_up:883
# target_path /home/user01/notebook/ASAN_DATA/Malignant/345/3/1.3.12.2.1107.5.1.4.66257.30000015092921284760300000885.dcm
# 345번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[35, 36, 37]
# top , buttom (289, 103) (319, 100)
# left , right (303, 85) (305, 112)
# top , buttom (293, 95) (323, 91)
# left , right (302, 85) (301, 115)
# top , buttom (298, 94) (322, 93)
# left , right (308, 81) (306, 107)
# 이미지를 crop 하고 저장합니다
# key 35
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:30
# target_key_up:34
# target_path /home/user01/notebook/ASAN_DATA/Malignant/346/3/1.3.12.2.1107.5.1.4.66417.30000015111521110211200001030.dcm
# key 36
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:29
# target_key_up:35
# target_path /home/user01/notebook/ASAN_DATA/Malignant/346/3/1.3.12.2.1107.5.1.4.66417.30000015111521110211200001029.dcm
# key 37
# target_key 시작 위치 :0
# target_key 끝 위치 :999
# target_key:28
# target_key_up:36
# target_path /home/user01/notebook/ASAN_DATA/Malignant/346/3/1.3.12.2.1107.5.1.4.66417.30000015111521110211200001028.dcm
# 346번째 data입니다.
# ['3', 'ROI_MASK']
# target_mask.keys():[40, 41, 42, 39]
# top , buttom (285, 232) (317, 219)
# left , right (296, 212) (291, 239)
# top , buttom (283, 229) (314, 224)
# left , right (299, 212) (291, 239)
# top , buttom (294, 225) (311, 220)
# left , right (306, 218) (294, 234)
# top , buttom (287, 211) (312, 229)
# left , right (288, 210) (294, 237)
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :60
# target_key 끝 위치 :117
# target_key:78
# target_key_up:99
# target_path /home/user01/notebook/ASAN_DATA/Malignant/347/3/1.3.12.2.1107.5.1.4.66417.30000015120621121259700000078.dcm
# key 41
# target_key 시작 위치 :60
# target_key 끝 위치 :117
# target_key:77
# target_key_up:100
# target_path /home/user01/notebook/ASAN_DATA/Malignant/347/3/1.3.12.2.1107.5.1.4.66417.30000015120621121259700000077.dcm
# key 42
# target_key 시작 위치 :60
# target_key 끝 위치 :117
# target_key:76
# target_key_up:101
# target_path /home/user01/notebook/ASAN_DATA/Malignant/347/3/1.3.12.2.1107.5.1.4.66417.30000015120621121259700000076.dcm
# key 39
# target_key 시작 위치 :60
# target_key 끝 위치 :117
# target_key:79
# target_key_up:98
# target_path /home/user01/notebook/ASAN_DATA/Malignant/347/3/1.3.12.2.1107.5.1.4.66417.30000015120621121259700000079.dcm
