# %%
import os
import numpy as np
import re
from operator import add
import dicom as dc
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# %%
def sort_by_number(list_):
    
    def atoi(text):
        return int(text) if text.isdigit() else text

    def natural_keys(text):
        return [ atoi(c) for c in re.split('(\d+)', text) ]
    ret_list=list_.sort(key = natural_keys)
    return ret_list

# %%
def get_number_from_list(list_):
    """
    모든 폴더에 있는 파일의 순서를 지정할수 있는 숫자를 얻어낸후 리스트로 리턴한다 
    """
    ret_list=[]
    for i,file_name in enumerate(list_):
        ret_list.append(get_number(file_name))
    ret_list=map(int ,ret_list)
    return ret_list
def get_number(file_name):
    """
    1.3.12.2.1107.5.1.4.51914.30000006121806122618700000702.dcm
    -->30000006121806122618700000702.dcm
    -->name[-4:]=0702
    """
    extension=file_name.split('.')[-1]
    name=file_name.split('.')[-2]
    name=name[-4:]
    """
    """
    return name
def make_dict(list_name , list_path):
    """
    key:02 value:1.3.12.2.1107.5.1.4.51914.30000006121806122618700000702.dcm
    """
    ret_dic={}
    for i,ele in enumerate(list_path):
        ret_dic[list_name[i]]=ele
    return ret_dic
def attach_(arg1 , arg2):
    """
    arg1=elsement_wise 로 붙일 것
    arg2=list
    /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/001/roimask_0013.dcm'
    """
    list_=[]
    for i in range(len(arg2)):        
        list_.append(arg1)
    list_add=map(add,list_,arg2)    
    return list_add

def find_mask(mask_dic):
    cancer_mask={}
    for i,ele in enumerate(mask_dic.keys()):

        dc_file=dc.read_file(mask_dic[ele])
        dc_img=dc_file.pixel_array
        np_img=np.asarray(dc_img)
   
        if np.mean(dc_img)>0:
            "마스크에서 종양의 여부를 식별합니다"+str(ele)+"번째에서 종양이 발견되었습니다"
            #print ele
            #print np.mean(np_img)
            cancer_mask[ele]=mask_dic[ele]
    return cancer_mask

# %%
def dicom_pixel(path):
    dc_file=dc.read_file(path)
    dc_img=dc_file.pixel_array
    return dc_img

# %%
def mask_locate(target_mask):
    locate_mask={}
    print "target_mask.keys():{}".format(target_mask.keys())
    for i,key in enumerate(target_mask.keys()):
        try:
            np_img=dicom_pixel(target_mask[key])
            row,col=np.shape(np_img)
            top_flag=False
            buttom_flag=False
            left_flag=False
            right_flag=False
            for r in range(row):
                if np.mean(np_img[r,:])>0 and top_flag==False:
                    #print r
                    top_line=np_img[r,:]>0
                    for i,ele in enumerate(top_line):
                        if ele==True:
                            top= (r,i)

                            break;

                    top_flag=True
                if top_flag==True and np.mean(np_img[r,:])==0 and buttom_flag==False:        
                    buttom_line=np_img[r-1,:]>0

                    #print r-1
                    for i,ele in enumerate(buttom_line):
                        if ele==True:
                            buttom= (r-1,i)
                            break;
                    buttom_flag=True
           

            left_flag=False
            right_flag=False
            crop_np_img=np_img[top[0]:buttom[0],:]
            for c in range(col):
                if left_flag == False and np.mean(np_img[top[0]:buttom[0],c])>0:
                    left_line = np_img[top[0]:buttom[0],c]>0
                    for i , ele in enumerate(left_line):
                        if ele==True:
                            #print i
                            left = (top[0]+i,c)
                            #print left
                            break;
                    left_flag=True
                if left_flag == True and right_flag==False and np.mean(np_img[top[0]:buttom[0],c])==0:
                    right_line =np_img[top[0]:buttom[0],c-1]>0
                    #print right_line
                    for i , ele in enumerate(right_line):
                        if ele==True:
                            #print i
                            right = (top[0]+i,c-1)
                            #print right
                            break;

                    right_flag =True
            
            center_row = ( buttom[0]-top[0])/2
            center_col = ( right[1]-left[1])/2
            center= (top[0]+center_row) , (left[1]+center_col)
            #print center
            locate_list=[top,buttom,left,right,center]
            locate_mask[key]=locate_list
        except :
            print "error info "
            print "mask : ",key
            print "mask location:",target_mask[key]
            continue;
        print 'top , buttom',top , buttom
        print 'left , right',left , right
    return locate_mask

# %%
a=[1,2,3]
b=[1,2,3]
attach_(1,a)
# Out:
# [2, 3, 4]

# %%
a=[1,2,3]

# %%
def crop_image(img , center, row,col):
    return img[center[0]-(row/2) : center[0]+(row/2) , center[1]-(col/2): center[1]+(col/2)]

# %%
def draw_rectangle_and_save(x,y,np_img ,save_path):

    # Create figure and axes
    fig,ax = plt.subplots(1)
    # Display the image
    ax.imshow(np_img)
    plt.savefig(save_path+'.png')
    
    # Create a Rectangle patch
    rect = patches.Rectangle((x,y),50,50,fill=True,linewidth=1,edgecolor='r',facecolor='none')
    # Add the patch to the Axes
    ax.add_patch(rect)
    
    plt.savefig(save_path+'_rect.png')
    plt.close(plt.gcf())

# %%
def crop_mask_target_images_save(mask_dic, mask_locate ,target_dic,save_path):

    print "이미지를 crop 하고 저장합니다 "
    """center 좌표를 이용해 mask 이미지와 target data의 이미지를 자른다
    mask data path 을 가지고 있는 arg: mask_dic
    center좌표를 가지고 있는 arg : mask_locate
    target data path 을 가지고 있는 arg : target_dic
    
    이미지로 저장하냐 
    numpy 로 저장 
    엔지니어 관점 문제점 파일을 2번 열어야 되서 효율성에서 떨어진다 코드를 수정해야 한다.
    넘피로도 저장을 해야 한다 .
    
    target_dic.keys()이가 항상 오름차순이라고 가정한다. 
    확인 하는 코드를 넣어야 한다.
    """
    for i ,key in enumerate(mask_dic.keys()):
        print 'key',key
        #print 'key type' ,type(key)
        key=int(key)
        mask_path=mask_dic[key]
        target_list=sorted(target_dic.keys())
        target_key=target_list[-key]
        target_key_up=target_list[key-1]
        print 'target_key 시작 위치 :'+str(target_list[0])
        print 'target_key 끝 위치 :'+str(target_list[-1])
        
        print 'target_key:'+str(target_key)
        print 'target_key_up:'+str(target_key_up)
        target_path=target_dic[target_key]
        target_path_up=target_dic[target_key_up]
        print 'target_path',target_path
        mask_img=dicom_pixel(mask_path)
        target_img=dicom_pixel(target_path)
        target_img_up=dicom_pixel(target_path_up)
        
        
        
        center=mask_locate[key][4]
        crop_mask_img=crop_image(mask_img  , center , 100 , 100)
        crop_target_img=crop_image(target_img  , center , 100 , 100)
        crop_target_img_up=crop_image(target_img_up  , center , 100 , 100)
        
        mkdir(save_path,str(target_key))
        
        draw_rec_mask_img=draw_rectangle_and_save(25,25,crop_target_img_up,save_path+'/'+str(target_key)+'/crop_target_up_'+str(target_key_up))
        draw_rec_mask_img=draw_rectangle_and_save(25,25,crop_target_img,save_path+'/'+str(target_key)+'/crop_target_'+str(target_key))
        draw_rec_target_img=draw_rectangle_and_save(25,25,crop_mask_img,save_path+'/'+str(target_key)+'/crop_mask_'+str(key))
        
        draw_rec_target_img=draw_rectangle_and_save(center[1]-25,center[0]-25,target_img_up,save_path+'/'+str(target_key)+'/target_up_'+str(target_key_up))
        draw_rec_target_img=draw_rectangle_and_save(center[1]-25,center[0]-25,target_img,save_path+'/'+str(target_key)+'/target_'+str(target_key))
        draw_rec_target_img=draw_rectangle_and_save(center[1]-25,center[0]-25,mask_img,save_path+'/'+str(target_key)+'/mask_'+str(key))

# %%
def mkdir(path,name=None , secceed_on=True):
    if os.path.isdir(path)==False:
        os.mkdir(path)
    if os.path.isdir(path)==True:
        if name != None and os.path.isdir(path+'/'+name)==False:
            os.mkdir(path+'/'+name)

# %%
folder_path='/home/seongjung/ASAN_project1/project1/CCM_Data/Benign/'
save_foler='/home/seongjung/ASAN_DATA/Benign_new'
folder_list = os.walk(folder_path).next()[1]
folder_list=sorted(folder_list) #오름 차순으로 정리

# %%
for i,ele in enumerate(folder_list):
    try:
        print str(i)+'번째 data입니다.'
        subFolder_path=folder_path+ele
        subFolder_list=os.walk(subFolder_path).next()[1]
        print 'subFolder_list',subFolder_list 
        if 'ROI_MASK' in subFolder_list:
            print 'b'
            mask_list=os.walk(subFolder_path+'/ROI_MASK').next()[2] #...CCM_Data/Malignant/001'
            mask_path=attach_(subFolder_path+'/ROI_MASK'+'/',mask_list)
            mask_number=get_number_from_list(mask_list) #roimask_0002-->02
            mask_dic=make_dict(mask_number,mask_path)

            ct_list=os.walk(subFolder_path+'/'+subFolder_list[1]+'/').next()[2]
            ct_path=attach_(subFolder_path+'/'+subFolder_list[1]+'/',ct_list)
            ct_number=get_number_from_list(ct_list) #roimask_0002-->02
            ct_dic=make_dict(ct_number,ct_path)

            #print ct_dic.keys(); print ct_dic.values()
            cancer_mask_dic=find_mask(mask_dic)
            cancer_mask_locate=mask_locate(cancer_mask_dic)
            # cancer_mask_locate :top,buttom,left,right,center
            save_path = save_foler+'/'+ele
            if os.path.isdir(save_path)==True:
                continue;
            print 'a'
            crop_mask_target_images_save(cancer_mask_dic, cancer_mask_locate , ct_dic ,save_path)
    except Exception as e:
        print str(e);
        continue;
        
        """
        에러가 뜨는 이유는 확실히다 처음 암 영역이 나온 이후 다시 
        나오기 때문이다. 그 알고리즈을 넣어야 한다 .
        
        """
# Out:
# 0번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[12]
# top , buttom (320, 61) (333, 66)
# left , right (324, 58) (325, 71)
# a
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :701
# target_key 끝 위치 :716
# target_key:705
# target_key_up:712
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/001/3/1.3.12.2.1107.5.1.4.51914.30000006121806122618700000705.dcm
# 1번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[10]
# top , buttom (308, 209) (325, 214)
# left , right (315, 206) (316, 218)
# a
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :2267
# target_key 끝 위치 :2286
# target_key:2277
# target_key_up:2276
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/002/3/1.3.12.2.1107.5.1.4.51914.30000006022707104076500022277.dcm
# 2번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[19]
# error info
# mask :  19
# mask location: /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/003/ROI_MASK/roimask_0019.dcm
# a
# 이미지를 crop 하고 저장합니다
# key 19
# target_key 시작 위치 :3299
# target_key 끝 위치 :3334
# target_key:3316
# target_key_up:3317
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/003/3/1.3.12.2.1107.5.1.4.50122.30000006082314543246800053316.dcm
# 19
# 3번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[18]
# top , buttom (224, 353) (242, 336)
# left , right (233, 327) (224, 354)
# a
# 이미지를 crop 하고 저장합니다
# key 18
# target_key 시작 위치 :697
# target_key 끝 위치 :761
# target_key:744
# target_key_up:714
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/004/3/1.3.12.2.1107.5.1.4.65211.30000011100321164867100030744.dcm
# 4번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[32]
# top , buttom (312, 127) (350, 134)
# left , right (334, 121) (324, 154)
# a
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :5641
# target_key 끝 위치 :5700
# target_key:5669
# target_key_up:5672
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/005/3/1.3.12.2.1107.5.1.4.66256.30000013061622140489300015669.dcm
# 5번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[17]
# top , buttom (211, 166) (225, 169)
# left , right (218, 160) (222, 172)
# a
# 이미지를 crop 하고 저장합니다
# key 17
# target_key 시작 위치 :3836
# target_key 끝 위치 :3900
# target_key:3884
# target_key_up:3852
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/006/3/1.3.12.2.1107.5.1.4.66417.30000014050722182071100003884.dcm
# 6번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[39]
# top , buttom (324, 144) (348, 130)
# left , right (334, 120) (340, 145)
# a
# 이미지를 crop 하고 저장합니다
# key 39
# target_key 시작 위치 :7731
# target_key 끝 위치 :7806
# target_key:7768
# target_key_up:7769
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/007/3/1.3.12.2.1107.5.1.4.64716.30000013031917054398400007768.dcm
# 7번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[25]
# top , buttom (147, 108) (181, 112)
# left , right (166, 95) (164, 123)
# a
# 이미지를 crop 하고 저장합니다
# key 25
# target_key 시작 위치 :4951
# target_key 끝 위치 :5005
# target_key:4981
# target_key_up:4975
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/008/4/1.3.12.2.1107.5.1.4.66256.30000013032422161612600014981.dcm
# 8번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[30, 31]
# top , buttom (133, 191) (154, 186)
# left , right (141, 178) (142, 200)
# top , buttom (139, 189) (151, 189)
# left , right (142, 182) (141, 196)
# a
# 이미지를 crop 하고 저장합니다
# key 30
# target_key 시작 위치 :1338
# target_key 끝 위치 :1407
# target_key:1378
# target_key_up:1367
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/009/3/1.3.12.2.1107.5.1.4.51914.30000013040506225026500001378.dcm
# key 31
# target_key 시작 위치 :1338
# target_key 끝 위치 :1407
# target_key:1377
# target_key_up:1368
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/009/3/1.3.12.2.1107.5.1.4.51914.30000013040506225026500001377.dcm
# 9번째 data입니다.
# subFolder_list ['ROI_MASK', '9']
# b
# target_mask.keys():[24, 23]
# top , buttom (339, 155) (360, 148)
# left , right (351, 141) (354, 156)
# top , buttom (349, 150) (363, 149)
# left , right (355, 146) (353, 157)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :7516
# target_key 끝 위치 :7550
# target_key:7527
# target_key_up:7539
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/010/9/1.3.12.2.1107.5.1.4.51698.30000010102122173426500007527.dcm
# key 23
# target_key 시작 위치 :7516
# target_key 끝 위치 :7550
# target_key:7528
# target_key_up:7538
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/010/9/1.3.12.2.1107.5.1.4.51698.30000010102122173426500007528.dcm
# 10번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[24, 25, 23]
# top , buttom (330, 172) (360, 159)
# left , right (349, 153) (338, 183)
# top , buttom (332, 170) (356, 177)
# left , right (345, 159) (342, 183)
# top , buttom (341, 162) (362, 169)
# left , right (347, 153) (354, 175)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :8255
# target_key 끝 위치 :8326
# target_key:8303
# target_key_up:8278
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/011/3/1.3.12.2.1107.5.1.4.73145.30000015040621254222100018303.dcm
# key 25
# target_key 시작 위치 :8255
# target_key 끝 위치 :8326
# target_key:8302
# target_key_up:8279
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/011/3/1.3.12.2.1107.5.1.4.73145.30000015040621254222100018302.dcm
# key 23
# target_key 시작 위치 :8255
# target_key 끝 위치 :8326
# target_key:8304
# target_key_up:8277
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/011/3/1.3.12.2.1107.5.1.4.73145.30000015040621254222100018304.dcm
# 11번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[14]
# top , buttom (284, 306) (305, 308)
# left , right (288, 301) (295, 318)
# a
# 이미지를 crop 하고 저장합니다
# key 14
# target_key 시작 위치 :941
# target_key 끝 위치 :958
# target_key:945
# target_key_up:954
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/012/3/1.3.12.2.1107.5.1.4.50122.30000007090321142978100000945.dcm
# 12번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[17, 18, 19, 20, 21]
# top , buttom (244, 177) (261, 191)
# left , right (244, 177) (258, 193)
# top , buttom (241, 184) (272, 185)
# left , right (253, 172) (256, 205)
# top , buttom (239, 185) (273, 185)
# left , right (253, 168) (262, 210)
# top , buttom (238, 193) (270, 182)
# left , right (251, 167) (256, 209)
# top , buttom (243, 181) (267, 191)
# left , right (248, 166) (257, 210)
# a
# 이미지를 crop 하고 저장합니다
# key 17
# target_key 시작 위치 :9322
# target_key 끝 위치 :9396
# target_key:9380
# target_key_up:9338
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039380.dcm
# key 18
# target_key 시작 위치 :9322
# target_key 끝 위치 :9396
# target_key:9379
# target_key_up:9339
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039379.dcm
# key 19
# target_key 시작 위치 :9322
# target_key 끝 위치 :9396
# target_key:9378
# target_key_up:9340
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039378.dcm
# key 20
# target_key 시작 위치 :9322
# target_key 끝 위치 :9396
# target_key:9377
# target_key_up:9341
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039377.dcm
# key 21
# target_key 시작 위치 :9322
# target_key 끝 위치 :9396
# target_key:9376
# target_key_up:9342
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/013/3/1.3.12.2.1107.5.1.4.66256.30000015020221363441800039376.dcm
# 13번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[25, 26]
# top , buttom (217, 89) (229, 89)
# left , right (218, 87) (225, 102)
# top , buttom (216, 94) (230, 90)
# left , right (221, 87) (221, 101)
# a
# 이미지를 crop 하고 저장합니다
# key 25
# target_key 시작 위치 :3330
# target_key 끝 위치 :3393
# target_key:3369
# target_key_up:3354
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/014/3/1.3.12.2.1107.5.1.4.51914.30000011072704295728100013369.dcm
# key 26
# target_key 시작 위치 :3330
# target_key 끝 위치 :3393
# target_key:3368
# target_key_up:3355
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/014/3/1.3.12.2.1107.5.1.4.51914.30000011072704295728100013368.dcm
# 14번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[24, 25, 26, 27, 28]
# top , buttom (258, 374) (289, 369)
# left , right (275, 357) (278, 392)
# top , buttom (256, 369) (291, 369)
# left , right (266, 354) (268, 393)
# top , buttom (254, 366) (290, 372)
# left , right (268, 349) (269, 392)
# top , buttom (255, 364) (287, 375)
# left , right (275, 356) (274, 389)
# top , buttom (262, 366) (278, 371)
# left , right (266, 363) (272, 379)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :1304
# target_key 끝 위치 :1377
# target_key:1354
# target_key_up:1327
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001354.dcm
# key 25
# target_key 시작 위치 :1304
# target_key 끝 위치 :1377
# target_key:1353
# target_key_up:1328
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001353.dcm
# key 26
# target_key 시작 위치 :1304
# target_key 끝 위치 :1377
# target_key:1352
# target_key_up:1329
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001352.dcm
# key 27
# target_key 시작 위치 :1304
# target_key 끝 위치 :1377
# target_key:1351
# target_key_up:1330
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001351.dcm
# key 28
# target_key 시작 위치 :1304
# target_key 끝 위치 :1377
# target_key:1350
# target_key_up:1331
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/015/4/1.3.12.2.1107.5.1.4.65211.30000014050722090514000001350.dcm
# 15번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[32, 33, 34, 35]
# top , buttom (348, 316) (388, 318)
# left , right (369, 307) (362, 341)
# top , buttom (348, 325) (394, 320)
# left , right (360, 307) (368, 350)
# top , buttom (351, 324) (386, 319)
# left , right (364, 311) (380, 350)
# top , buttom (351, 324) (385, 334)
# left , right (359, 321) (362, 346)
# a
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :6855
# target_key 끝 위치 :6924
# target_key:6893
# target_key_up:6886
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006893.dcm
# key 33
# target_key 시작 위치 :6855
# target_key 끝 위치 :6924
# target_key:6892
# target_key_up:6887
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006892.dcm
# key 34
# target_key 시작 위치 :6855
# target_key 끝 위치 :6924
# target_key:6891
# target_key_up:6888
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006891.dcm
# key 35
# target_key 시작 위치 :6855
# target_key 끝 위치 :6924
# target_key:6890
# target_key_up:6889
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/016/3/1.3.12.2.1107.5.1.4.51698.30000012011423431520300006890.dcm
# 16번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[39]
# top , buttom (268, 436) (283, 429)
# left , right (274, 423) (272, 440)
# a
# 이미지를 crop 하고 저장합니다
# key 39
# target_key 시작 위치 :1488
# target_key 끝 위치 :1548
# target_key:1510
# target_key_up:1526
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/017/3/1.3.12.2.1107.5.1.4.51914.30000012050705090423400031510.dcm
# 17번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[20, 21, 22, 23]
# top , buttom (251, 315) (283, 327)
# left , right (251, 315) (264, 343)
# top , buttom (246, 333) (288, 335)
# left , right (258, 314) (285, 353)
# top , buttom (250, 331) (286, 332)
# left , right (261, 313) (257, 349)
# top , buttom (253, 324) (284, 326)
# left , right (264, 313) (262, 341)
# a
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :2088
# target_key 끝 위치 :2160
# target_key:2141
# target_key_up:2107
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002141.dcm
# key 21
# target_key 시작 위치 :2088
# target_key 끝 위치 :2160
# target_key:2140
# target_key_up:2108
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002140.dcm
# key 22
# target_key 시작 위치 :2088
# target_key 끝 위치 :2160
# target_key:2139
# target_key_up:2109
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002139.dcm
# key 23
# target_key 시작 위치 :2088
# target_key 끝 위치 :2160
# target_key:2138
# target_key_up:2110
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/018/3/1.3.12.2.1107.5.1.4.51914.30000012082201503575000002138.dcm
# 18번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[30, 31]
# top , buttom (246, 413) (269, 417)
# left , right (252, 407) (256, 428)
# top , buttom (245, 411) (268, 418)
# left , right (250, 405) (254, 424)
# a
# 이미지를 crop 하고 저장합니다
# key 30
# target_key 시작 위치 :9353
# target_key 끝 위치 :9420
# target_key:9391
# target_key_up:9382
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/019/3/1.3.12.2.1107.5.1.4.66257.30000015122121143646700029391.dcm
# key 31
# target_key 시작 위치 :9353
# target_key 끝 위치 :9420
# target_key:9390
# target_key_up:9383
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/019/3/1.3.12.2.1107.5.1.4.66257.30000015122121143646700029390.dcm
# 19번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[32, 31]
# top , buttom (139, 146) (156, 146)
# left , right (149, 133) (153, 157)
# top , buttom (139, 142) (152, 143)
# left , right (141, 138) (146, 153)
# a
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :3293
# target_key 끝 위치 :3365
# target_key:3334
# target_key_up:3324
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/020/3/1.3.12.2.1107.5.1.4.73145.30000011120722134846800003334.dcm
# key 31
# target_key 시작 위치 :3293
# target_key 끝 위치 :3365
# target_key:3335
# target_key_up:3323
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/020/3/1.3.12.2.1107.5.1.4.73145.30000011120722134846800003335.dcm
# 20번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[20, 21]
# top , buttom (177, 167) (202, 174)
# left , right (184, 159) (191, 193)
# top , buttom (177, 167) (190, 173)
# left , right (184, 162) (180, 178)
# a
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :6151
# target_key 끝 위치 :6189
# target_key:6170
# target_key_up:6170
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/021/3/1.3.12.2.1107.5.1.4.0.30000010101421384959300016170.dcm
# key 21
# target_key 시작 위치 :6151
# target_key 끝 위치 :6189
# target_key:6169
# target_key_up:6171
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/021/3/1.3.12.2.1107.5.1.4.0.30000010101421384959300016169.dcm
# 21번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[35, 36]
# top , buttom (324, 180) (353, 181)
# left , right (330, 171) (332, 201)
# top , buttom (321, 180) (353, 188)
# left , right (328, 168) (330, 202)
# a
# 이미지를 crop 하고 저장합니다
# key 35
# target_key 시작 위치 :2091
# target_key 끝 위치 :2160
# target_key:2126
# target_key_up:2125
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/022/3/1.3.12.2.1107.5.1.4.51914.30000013022506230898400002126.dcm
# key 36
# target_key 시작 위치 :2091
# target_key 끝 위치 :2160
# target_key:2125
# target_key_up:2126
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/022/3/1.3.12.2.1107.5.1.4.51914.30000013022506230898400002125.dcm
# 22번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[24, 25, 26]
# top , buttom (215, 188) (232, 184)
# left , right (222, 178) (224, 198)
# top , buttom (210, 190) (234, 183)
# left , right (223, 175) (220, 198)
# top , buttom (210, 190) (235, 194)
# left , right (218, 179) (227, 198)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :1255
# target_key 끝 위치 :1328
# target_key:1305
# target_key_up:1278
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/023/4/1.3.12.2.1107.5.1.4.64716.30000011051221311832800031305.dcm
# key 25
# target_key 시작 위치 :1255
# target_key 끝 위치 :1328
# target_key:1304
# target_key_up:1279
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/023/4/1.3.12.2.1107.5.1.4.64716.30000011051221311832800031304.dcm
# key 26
# target_key 시작 위치 :1255
# target_key 끝 위치 :1328
# target_key:1303
# target_key_up:1280
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/023/4/1.3.12.2.1107.5.1.4.64716.30000011051221311832800031303.dcm
# 23번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[28, 29, 30, 31]
# top , buttom (313, 403) (340, 400)
# left , right (335, 389) (331, 417)
# top , buttom (308, 402) (342, 399)
# left , right (334, 379) (329, 420)
# top , buttom (307, 399) (342, 394)
# left , right (325, 380) (324, 419)
# top , buttom (309, 392) (341, 401)
# left , right (321, 384) (330, 416)
# a
# 이미지를 crop 하고 저장합니다
# key 28
# target_key 시작 위치 :773
# target_key 끝 위치 :9421
# target_key:2572
# target_key_up:2345
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22230024251052572.dcm
# key 29
# target_key 시작 위치 :773
# target_key 끝 위치 :9421
# target_key:2465
# target_key_up:2399
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22229862319652465.dcm
# key 30
# target_key 시작 위치 :773
# target_key 끝 위치 :9421
# target_key:2399
# target_key_up:2465
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22230029331592399.dcm
# key 31
# target_key 시작 위치 :773
# target_key 끝 위치 :9421
# target_key:2345
# target_key_up:2572
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/024/3/1.3.12.2.1107.5.1.4.50122.4.0.22229898021842345.dcm
# 24번째 data입니다.
# subFolder_list ['ROI_MASK', '2']
# b
# target_mask.keys():[29, 30, 31]
# top , buttom (268, 338) (284, 340)
# left , right (277, 334) (274, 350)
# top , buttom (265, 343) (287, 338)
# left , right (275, 331) (269, 352)
# top , buttom (267, 346) (286, 346)
# left , right (281, 333) (280, 353)
# a
# 이미지를 crop 하고 저장합니다
# key 29
# target_key 시작 위치 :3755
# target_key 끝 위치 :3824
# target_key:3796
# target_key_up:3783
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/025/2/1.3.12.2.1107.5.1.4.50122.30000012040723144257800003796.dcm
# key 30
# target_key 시작 위치 :3755
# target_key 끝 위치 :3824
# target_key:3795
# target_key_up:3784
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/025/2/1.3.12.2.1107.5.1.4.50122.30000012040723144257800003795.dcm
# key 31
# target_key 시작 위치 :3755
# target_key 끝 위치 :3824
# target_key:3794
# target_key_up:3785
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/025/2/1.3.12.2.1107.5.1.4.50122.30000012040723144257800003794.dcm
# 25번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[12]
# top , buttom (285, 344) (322, 335)
# left , right (308, 320) (312, 355)
# a
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :4949
# target_key 끝 위치 :4966
# target_key:4955
# target_key_up:4960
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/026/3/1.3.12.2.1107.5.1.4.51698.30000007102106532668700004955.dcm
# 26번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[80, 81, 82, 83, 84, 85, 86, 87, 88, 89, 90, 91, 92]
# top , buttom (237, 122) (246, 120)
# left , right (240, 118) (239, 124)
# top , buttom (236, 120) (248, 119)
# left , right (241, 115) (241, 126)
# top , buttom (234, 122) (250, 120)
# left , right (241, 113) (238, 127)
# top , buttom (233, 121) (251, 120)
# left , right (240, 112) (238, 128)
# top , buttom (232, 122) (251, 117)
# left , right (242, 111) (236, 128)
# top , buttom (232, 119) (251, 116)
# left , right (244, 110) (240, 129)
# top , buttom (232, 118) (252, 118)
# left , right (235, 111) (239, 129)
# top , buttom (231, 121) (252, 119)
# left , right (234, 111) (240, 129)
# top , buttom (231, 120) (251, 117)
# left , right (239, 111) (242, 129)
# top , buttom (231, 118) (250, 117)
# left , right (242, 111) (241, 128)
# top , buttom (231, 116) (249, 117)
# left , right (242, 112) (238, 126)
# top , buttom (236, 118) (247, 117)
# left , right (244, 114) (238, 124)
# top , buttom (237, 120) (247, 116)
# left , right (239, 116) (240, 123)
# a
# 이미지를 crop 하고 저장합니다
# key 80
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:856
# target_key_up:895
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020856.dcm
# key 81
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:855
# target_key_up:896
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020855.dcm
# key 82
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:854
# target_key_up:897
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020854.dcm
# key 83
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:853
# target_key_up:898
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020853.dcm
# key 84
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:852
# target_key_up:899
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020852.dcm
# key 85
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:851
# target_key_up:900
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020851.dcm
# key 86
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:850
# target_key_up:901
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020850.dcm
# key 87
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:849
# target_key_up:902
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020849.dcm
# key 88
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:848
# target_key_up:903
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020848.dcm
# key 89
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:847
# target_key_up:904
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020847.dcm
# key 90
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:846
# target_key_up:905
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020846.dcm
# key 91
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:845
# target_key_up:906
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020845.dcm
# key 92
# target_key 시작 위치 :816
# target_key 끝 위치 :935
# target_key:844
# target_key_up:907
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/027/4/1.3.12.2.1107.5.1.4.50122.30000005112722084675000020844.dcm
# 27번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[9]
# top , buttom (173, 398) (205, 402)
# left , right (187, 387) (184, 421)
# a
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :2773
# target_key 끝 위치 :2792
# target_key:2784
# target_key_up:2781
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/028/3/1.3.12.2.1107.5.1.4.51698.30000006051911062317100002784.dcm
# 28번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[11]
# top , buttom (329, 349) (348, 346)
# left , right (344, 341) (332, 363)
# a
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :5048
# target_key 끝 위치 :5067
# target_key:5057
# target_key_up:5058
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/029/4/1.3.12.2.1107.5.1.4.50122.30000009121223332070300015057.dcm
# 29번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[8]
# top , buttom (195, 414) (217, 402)
# left , right (204, 396) (204, 419)
# a
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :7349
# target_key 끝 위치 :7364
# target_key:7357
# target_key_up:7356
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/030/3/1.3.12.2.1107.5.1.4.51698.30000007010510572973400027357.dcm
# 30번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 118, 119, 120, 121, 122, 123, 124]
# top , buttom (314, 172) (340, 172)
# left , right (324, 158) (316, 180)
# top , buttom (315, 167) (343, 172)
# left , right (324, 157) (325, 182)
# top , buttom (315, 163) (345, 171)
# left , right (328, 155) (323, 186)
# top , buttom (313, 167) (344, 171)
# left , right (329, 155) (323, 190)
# top , buttom (311, 170) (341, 172)
# left , right (331, 154) (321, 190)
# top , buttom (312, 165) (341, 168)
# left , right (323, 155) (322, 192)
# top , buttom (311, 166) (346, 168)
# left , right (323, 154) (320, 192)
# top , buttom (309, 168) (342, 170)
# left , right (321, 154) (323, 192)
# top , buttom (308, 166) (343, 165)
# left , right (325, 153) (323, 192)
# top , buttom (308, 167) (342, 172)
# left , right (322, 154) (320, 193)
# top , buttom (312, 164) (343, 170)
# left , right (321, 155) (320, 193)
# top , buttom (311, 165) (343, 170)
# left , right (322, 155) (324, 193)
# top , buttom (313, 164) (342, 167)
# left , right (322, 155) (324, 194)
# top , buttom (313, 166) (342, 168)
# left , right (320, 156) (324, 193)
# top , buttom (311, 168) (341, 172)
# left , right (320, 156) (327, 192)
# top , buttom (309, 166) (344, 178)
# left , right (320, 157) (328, 190)
# top , buttom (315, 167) (340, 167)
# left , right (321, 159) (332, 189)
# top , buttom (315, 172) (341, 173)
# left , right (323, 159) (332, 188)
# top , buttom (311, 170) (340, 174)
# left , right (325, 161) (332, 187)
# top , buttom (317, 170) (338, 171)
# left , right (327, 161) (333, 186)
# a
# 이미지를 crop 하고 저장합니다
# key 105
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1689
# target_key_up:4049
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257293529051689.dcm
# key 106
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1673
# target_key_up:4561
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257022530251673.dcm
# key 107
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1651
# target_key_up:4825
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257264247841651.dcm
# key 108
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1614
# target_key_up:4910
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257432316661614.dcm
# key 109
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1588
# target_key_up:5580
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257221028021588.dcm
# key 110
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1585
# target_key_up:5769
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257138426251585.dcm
# key 111
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1562
# target_key_up:6015
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.2325723161921562.dcm
# key 112
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1561
# target_key_up:6048
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257273110811561.dcm
# key 113
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1486
# target_key_up:6119
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257027677251486.dcm
# key 114
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1472
# target_key_up:6149
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257188470591472.dcm
# key 115
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1426
# target_key_up:6488
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257140124251426.dcm
# key 116
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1409
# target_key_up:6704
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257286743971409.dcm
# key 117
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1368
# target_key_up:6855
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257074827371368.dcm
# key 118
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1327
# target_key_up:6868
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257167623171327.dcm
# key 119
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1315
# target_key_up:7660
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257048023241315.dcm
# key 120
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1263
# target_key_up:7706
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257119325211263.dcm
# key 121
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1235
# target_key_up:7971
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257215985331235.dcm
# key 122
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1231
# target_key_up:8110
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257265928651231.dcm
# key 123
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1176
# target_key_up:8257
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257025916081176.dcm
# key 124
# target_key 시작 위치 :1053
# target_key 끝 위치 :9764
# target_key:1156
# target_key_up:8519
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/031/3/1.3.12.2.1107.5.1.4.50122.4.0.23257243511651156.dcm
# 31번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[8]
# top , buttom (202, 101) (232, 109)
# left , right (210, 97) (209, 116)
# a
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :240
# target_key 끝 위치 :254
# target_key:247
# target_key_up:247
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/032/3/1.3.12.2.1107.5.1.4.50122.30000009110522100664000030247.dcm
# 32번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[7]
# top , buttom (186, 185) (205, 179)
# left , right (196, 171) (192, 191)
# a
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :2771
# target_key 끝 위치 :2789
# target_key:2783
# target_key_up:2777
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/033/3/1.3.12.2.1107.5.1.4.50122.30000009101122073135900002783.dcm
# 33번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[9]
# top , buttom (254, 358) (273, 360)
# left , right (261, 344) (262, 373)
# a
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :47
# target_key 끝 위치 :63
# target_key:55
# target_key_up:55
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/034/3/1.3.12.2.1107.5.1.4.50122.30000008040823461129600000055.dcm
# 34번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[18]
# top , buttom (282, 344) (296, 343)
# left , right (286, 338) (285, 355)
# a
# 이미지를 crop 하고 저장합니다
# key 18
# target_key 시작 위치 :5020
# target_key 끝 위치 :5064
# target_key:5047
# target_key_up:5037
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/035/3/1.3.12.2.1107.5.1.4.51914.30000010102207193750000025047.dcm
# 35번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[5]
# top , buttom (300, 319) (328, 313)
# left , right (314, 309) (314, 348)
# a
# 이미지를 crop 하고 저장합니다
# key 5
# target_key 시작 위치 :2432
# target_key 끝 위치 :2447
# target_key:2443
# target_key_up:2436
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/036/3/1.3.12.2.1107.5.1.4.51914.30000009072305130043700012443.dcm
# 36번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[10]
# top , buttom (243, 143) (274, 146)
# left , right (256, 130) (264, 168)
# a
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :6399
# target_key 끝 위치 :6416
# target_key:6407
# target_key_up:6408
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/037/3/1.3.12.2.1107.5.1.4.51914.30000006090505233182800006407.dcm
# 37번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[9]
# top , buttom (284, 411) (300, 412)
# left , right (290, 408) (292, 421)
# a
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :6825
# target_key 끝 위치 :6844
# target_key:6836
# target_key_up:6833
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/038/3/1.3.12.2.1107.5.1.4.50122.30000009110922103810900006836.dcm
# 38번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[14]
# top , buttom (254, 183) (279, 188)
# left , right (272, 170) (271, 195)
# a
# 이미지를 crop 하고 저장합니다
# key 14
# target_key 시작 위치 :7606
# target_key 끝 위치 :7625
# target_key:7612
# target_key_up:7619
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/039/3/1.3.12.2.1107.5.1.4.51698.30000006092705203528100017612.dcm
# 39번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[11]
# top , buttom (254, 129) (270, 124)
# left , right (260, 120) (261, 139)
# a
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :4089
# target_key 끝 위치 :4105
# target_key:4095
# target_key_up:4099
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/040/3/1.3.12.2.1107.5.1.4.51698.30000009062822064573400004095.dcm
# 40번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[8]
# top , buttom (261, 355) (298, 352)
# left , right (272, 341) (279, 377)
# a
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :2
# target_key 끝 위치 :19
# target_key:12
# target_key_up:9
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/041/3/1.3.12.2.1107.5.1.4.51914.30000006100905202520300000012.dcm
# 41번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[9]
# top , buttom (163, 377) (197, 384)
# left , right (177, 371) (184, 401)
# a
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :2365
# target_key 끝 위치 :2380
# target_key:2372
# target_key_up:2373
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/042/3/1.3.12.2.1107.5.1.4.50122.30000007012522161959300022372.dcm
# 42번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[31]
# top , buttom (293, 418) (312, 417)
# left , right (300, 410) (300, 426)
# a
# 이미지를 crop 하고 저장합니다
# key 31
# target_key 시작 위치 :6624
# target_key 끝 위치 :6683
# target_key:6653
# target_key_up:6654
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/043/3/1.3.12.2.1107.5.1.4.83202.30000015081423382901200016653.dcm
# 43번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[9]
# top , buttom (318, 155) (337, 158)
# left , right (323, 151) (328, 172)
# a
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :9469
# target_key 끝 위치 :9487
# target_key:9479
# target_key_up:9477
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/044/3/1.3.12.2.1107.5.1.4.51914.30000007052805201420300019479.dcm
# 44번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[10, 7]
# top , buttom (160, 151) (197, 167)
# left , right (176, 144) (170, 180)
# top , buttom (235, 363) (245, 371)
# left , right (238, 361) (237, 374)
# a
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :3667
# target_key 끝 위치 :3681
# target_key:3672
# target_key_up:3676
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/045/4/1.3.12.2.1107.5.1.4.51698.30000008122922075679600023672.dcm
# key 7
# target_key 시작 위치 :3667
# target_key 끝 위치 :3681
# target_key:3675
# target_key_up:3673
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/045/4/1.3.12.2.1107.5.1.4.51698.30000008122922075679600023675.dcm
# 45번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[12]
# top , buttom (256, 324) (283, 317)
# left , right (267, 309) (265, 337)
# a
# 이미지를 crop 하고 저장합니다
# key 12
# target_key 시작 위치 :2783
# target_key 끝 위치 :2801
# target_key:2790
# target_key_up:2794
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/046/3/1.3.12.2.1107.5.1.4.51914.30000008061604381298400032790.dcm
# 46번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[44, 45, 46, 47]
# top , buttom (273, 177) (291, 182)
# left , right (278, 174) (281, 192)
# top , buttom (269, 174) (291, 175)
# left , right (275, 167) (280, 194)
# top , buttom (269, 186) (292, 175)
# left , right (279, 167) (281, 194)
# top , buttom (278, 178) (292, 175)
# left , right (290, 172) (280, 191)
# a
# 이미지를 crop 하고 저장합니다
# key 44
# target_key 시작 위치 :6367
# target_key 끝 위치 :6439
# target_key:6396
# target_key_up:6410
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006396.dcm
# key 45
# target_key 시작 위치 :6367
# target_key 끝 위치 :6439
# target_key:6395
# target_key_up:6411
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006395.dcm
# key 46
# target_key 시작 위치 :6367
# target_key 끝 위치 :6439
# target_key:6394
# target_key_up:6412
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006394.dcm
# key 47
# target_key 시작 위치 :6367
# target_key 끝 위치 :6439
# target_key:6393
# target_key_up:6413
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/047/3/1.3.12.2.1107.5.1.4.65211.30000012041121141470300006393.dcm
# 47번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[8]
# top , buttom (200, 142) (230, 133)
# left , right (209, 122) (222, 157)
# a
# 이미지를 crop 하고 저장합니다
# key 8
# target_key 시작 위치 :1781
# target_key 끝 위치 :1797
# target_key:1790
# target_key_up:1788
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/048/3/1.3.12.2.1107.5.1.4.50122.30000008101221295062500001790.dcm
# 48번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[7]
# top , buttom (297, 333) (340, 345)
# left , right (318, 308) (325, 353)
# a
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :661
# target_key 끝 위치 :678
# target_key:672
# target_key_up:667
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/049/3/1.3.12.2.1107.5.1.4.51914.30000008091604134812500030672.dcm
# 49번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[26]
# top , buttom (273, 421) (289, 424)
# left , right (280, 416) (276, 430)
# a
# 이미지를 crop 하고 저장합니다
# key 26
# target_key 시작 위치 :4211
# target_key 끝 위치 :4268
# target_key:4243
# target_key_up:4236
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/050/3/1.3.12.2.1107.5.1.4.66256.30000015011521244105600034243.dcm
# 50번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[10]
# top , buttom (296, 126) (319, 124)
# left , right (304, 115) (305, 137)
# a
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :7757
# target_key 끝 위치 :7773
# target_key:7764
# target_key_up:7766
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/051/3/1.3.12.2.1107.5.1.4.50122.30000009112922021559300037764.dcm
# 51번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[11]
# top , buttom (124, 186) (139, 186)
# left , right (130, 181) (134, 194)
# a
# 이미지를 crop 하고 저장합니다
# key 11
# target_key 시작 위치 :2627
# target_key 끝 위치 :2655
# target_key:2645
# target_key_up:2637
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/052/3/1.3.12.2.1107.5.1.4.50122.30000010053021170260900002645.dcm
# 52번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[9]
# top , buttom (260, 370) (282, 373)
# left , right (272, 365) (275, 393)
# a
# 이미지를 crop 하고 저장합니다
# key 9
# target_key 시작 위치 :452
# target_key 끝 위치 :467
# target_key:459
# target_key_up:460
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/053/3/1.3.12.2.1107.5.1.4.51914.30000010011707360689000000459.dcm
# 53번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[42, 43]
# top , buttom (273, 396) (295, 399)
# left , right (277, 390) (288, 411)
# top , buttom (271, 396) (298, 400)
# left , right (282, 390) (279, 411)
# a
# 이미지를 crop 하고 저장합니다
# key 42
# target_key 시작 위치 :4850
# target_key 끝 위치 :4916
# target_key:4875
# target_key_up:4891
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/054/3/1.3.12.2.1107.5.1.4.66257.30000015040821453883800014875.dcm
# key 43
# target_key 시작 위치 :4850
# target_key 끝 위치 :4916
# target_key:4874
# target_key_up:4892
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/054/3/1.3.12.2.1107.5.1.4.66257.30000015040821453883800014874.dcm
# 54번째 data입니다.
# subFolder_list ['ROI_MASK', '6']
# b
# target_mask.keys():[34]
# top , buttom (328, 95) (356, 100)
# left , right (336, 85) (336, 110)
# a
# 이미지를 crop 하고 저장합니다
# key 34
# target_key 시작 위치 :2451
# target_key 끝 위치 :2527
# target_key:2494
# target_key_up:2484
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/055/6/1.3.12.2.1107.5.1.4.65211.30000012031221233120300032494.dcm
# 55번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[7]
# top , buttom (196, 197) (237, 192)
# left , right (218, 177) (202, 217)
# a
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :5140
# target_key 끝 위치 :5156
# target_key:5150
# target_key_up:5146
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/056/3/1.3.12.2.1107.5.1.4.51914.30000010042704154726500035150.dcm
# 56번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[20]
# top , buttom (291, 155) (312, 159)
# left , right (298, 146) (303, 169)
# a
# 이미지를 crop 하고 저장합니다
# key 20
# target_key 시작 위치 :2585
# target_key 끝 위치 :2617
# target_key:2598
# target_key_up:2604
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/057/3/1.3.12.2.1107.5.1.4.51698.30000010092822071225000042598.dcm
# 57번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[7]
# top , buttom (312, 333) (336, 329)
# left , right (318, 320) (326, 343)
# a
# 이미지를 crop 하고 저장합니다
# key 7
# target_key 시작 위치 :4158
# target_key 끝 위치 :4184
# target_key:4178
# target_key_up:4164
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/058/3/1.3.12.2.1107.5.1.4.50122.30000010072021132912500004178.dcm
# 58번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[48, 49, 50]
# top , buttom (284, 200) (303, 201)
# left , right (293, 192) (299, 213)
# top , buttom (284, 200) (310, 201)
# left , right (293, 191) (297, 211)
# top , buttom (289, 200) (304, 208)
# left , right (295, 195) (302, 210)
# a
# 이미지를 crop 하고 저장합니다
# key 48
# target_key 시작 위치 :9636
# target_key 끝 위치 :9708
# target_key:9661
# target_key_up:9683
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/059/3/1.3.12.2.1107.5.1.4.50122.30000013022422082659300019661.dcm
# key 49
# target_key 시작 위치 :9636
# target_key 끝 위치 :9708
# target_key:9660
# target_key_up:9684
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/059/3/1.3.12.2.1107.5.1.4.50122.30000013022422082659300019660.dcm
# key 50
# target_key 시작 위치 :9636
# target_key 끝 위치 :9708
# target_key:9659
# target_key_up:9685
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/059/3/1.3.12.2.1107.5.1.4.50122.30000013022422082659300019659.dcm
# 59번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[10, 11]
# top , buttom (217, 219) (254, 207)
# left , right (230, 198) (233, 235)
# top , buttom (217, 221) (252, 217)
# left , right (240, 202) (231, 236)
# a
# 이미지를 crop 하고 저장합니다
# key 10
# target_key 시작 위치 :71
# target_key 끝 위치 :107
# target_key:98
# target_key_up:80
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/060/3/1.3.12.2.1107.5.1.4.51914.30000010101105153268700010098.dcm
# key 11
# target_key 시작 위치 :71
# target_key 끝 위치 :107
# target_key:97
# target_key_up:81
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/060/3/1.3.12.2.1107.5.1.4.51914.30000010101105153268700010097.dcm
# 60번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[54, 55]
# top , buttom (342, 383) (358, 385)
# left , right (349, 378) (346, 393)
# top , buttom (342, 384) (359, 388)
# left , right (348, 377) (347, 394)
# a
# 이미지를 crop 하고 저장합니다
# key 54
# target_key 시작 위치 :8970
# target_key 끝 위치 :9041
# target_key:8988
# target_key_up:9023
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/061/4/1.3.12.2.1107.5.1.4.65211.30000011063021185384300018988.dcm
# key 55
# target_key 시작 위치 :8970
# target_key 끝 위치 :9041
# target_key:8987
# target_key_up:9024
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/061/4/1.3.12.2.1107.5.1.4.65211.30000011063021185384300018987.dcm
# 61번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[40, 41, 42, 39]
# top , buttom (327, 335) (359, 331)
# left , right (351, 325) (340, 344)
# top , buttom (324, 334) (361, 336)
# left , right (350, 319) (335, 346)
# top , buttom (326, 334) (354, 327)
# left , right (340, 318) (342, 342)
# top , buttom (335, 336) (354, 331)
# left , right (347, 331) (346, 344)
# a
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :2599
# target_key 끝 위치 :2657
# target_key:2618
# target_key_up:2638
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002618.dcm
# key 41
# target_key 시작 위치 :2599
# target_key 끝 위치 :2657
# target_key:2617
# target_key_up:2639
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002617.dcm
# key 42
# target_key 시작 위치 :2599
# target_key 끝 위치 :2657
# target_key:2616
# target_key_up:2640
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002616.dcm
# key 39
# target_key 시작 위치 :2599
# target_key 끝 위치 :2657
# target_key:2619
# target_key_up:2637
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/062/4/1.3.12.2.1107.5.1.4.50122.30000011051721284228100002619.dcm
# 62번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[24, 23]
# top , buttom (277, 383) (295, 384)
# left , right (284, 376) (287, 398)
# top , buttom (276, 389) (294, 386)
# left , right (285, 378) (282, 395)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :5631
# target_key 끝 위치 :5700
# target_key:5677
# target_key_up:5654
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/063/3/1.3.12.2.1107.5.1.4.65211.30000011050221132051500005677.dcm
# key 23
# target_key 시작 위치 :5631
# target_key 끝 위치 :5700
# target_key:5678
# target_key_up:5653
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/063/3/1.3.12.2.1107.5.1.4.65211.30000011050221132051500005678.dcm
# 63번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[21]
# top , buttom (260, 61) (282, 68)
# left , right (265, 57) (273, 78)
# a
# 이미지를 crop 하고 저장합니다
# key 21
# target_key 시작 위치 :2282
# target_key 끝 위치 :2332
# target_key:2312
# target_key_up:2302
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/064/3/1.3.12.2.1107.5.1.4.50122.30000011053021272156200022312.dcm
# 64번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[40]
# top , buttom (306, 334) (322, 331)
# left , right (313, 326) (313, 345)
# a
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :4712
# target_key 끝 위치 :4773
# target_key:4734
# target_key_up:4751
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/065/3/1.3.12.2.1107.5.1.4.65211.30000011071421155470300014734.dcm
# 65번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[43, 44, 45]
# top , buttom (319, 170) (334, 166)
# left , right (323, 163) (325, 181)
# top , buttom (310, 167) (340, 184)
# left , right (320, 156) (323, 185)
# top , buttom (310, 174) (333, 167)
# left , right (324, 159) (323, 184)
# a
# 이미지를 crop 하고 저장합니다
# key 43
# target_key 시작 위치 :1081
# target_key 끝 위치 :1143
# target_key:1101
# target_key_up:1123
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/066/3/1.3.12.2.1107.5.1.4.51914.30000012020605104837500031101.dcm
# key 44
# target_key 시작 위치 :1081
# target_key 끝 위치 :1143
# target_key:1100
# target_key_up:1124
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/066/3/1.3.12.2.1107.5.1.4.51914.30000012020605104837500031100.dcm
# key 45
# target_key 시작 위치 :1081
# target_key 끝 위치 :1143
# target_key:1099
# target_key_up:1125
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/066/3/1.3.12.2.1107.5.1.4.51914.30000012020605104837500031099.dcm
# 66번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[21, 22]
# top , buttom (236, 386) (246, 389)
# left , right (239, 381) (238, 395)
# top , buttom (232, 383) (248, 384)
# left , right (242, 378) (236, 394)
# a
# 이미지를 crop 하고 저장합니다
# key 21
# target_key 시작 위치 :6078
# target_key 끝 위치 :6131
# target_key:6111
# target_key_up:6098
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/067/3/1.3.12.2.1107.5.1.4.50122.30000012041222092062500036111.dcm
# key 22
# target_key 시작 위치 :6078
# target_key 끝 위치 :6131
# ...
# target_key_up:4144
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/076/3/1.3.12.2.1107.5.1.4.51698.30000012051021305104600024173.dcm
# key 23
# target_key 시작 위치 :4123
# target_key 끝 위치 :4194
# target_key:4172
# target_key_up:4145
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/076/3/1.3.12.2.1107.5.1.4.51698.30000012051021305104600024172.dcm
# 76번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[32, 33, 31]
# top , buttom (306, 368) (324, 375)
# left , right (315, 366) (312, 388)
# top , buttom (306, 380) (324, 376)
# left , right (314, 369) (307, 385)
# top , buttom (304, 383) (317, 368)
# left , right (316, 367) (308, 385)
# a
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :5229
# target_key 끝 위치 :5285
# target_key:5254
# target_key_up:5260
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/077/3/1.3.12.2.1107.5.1.4.66256.30000014102121292412000045254.dcm
# key 33
# target_key 시작 위치 :5229
# target_key 끝 위치 :5285
# target_key:5253
# target_key_up:5261
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/077/3/1.3.12.2.1107.5.1.4.66256.30000014102121292412000045253.dcm
# key 31
# target_key 시작 위치 :5229
# target_key 끝 위치 :5285
# target_key:5255
# target_key_up:5259
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/077/3/1.3.12.2.1107.5.1.4.66256.30000014102121292412000045255.dcm
# 77번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[32, 33, 34]
# top , buttom (239, 144) (248, 141)
# left , right (242, 139) (244, 148)
# top , buttom (234, 142) (255, 144)
# left , right (238, 131) (244, 153)
# top , buttom (235, 141) (255, 141)
# left , right (243, 133) (242, 152)
# a
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :5815
# target_key 끝 위치 :5886
# target_key:5855
# target_key_up:5846
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/078/3/1.3.12.2.1107.5.1.4.65211.30000012061121143587500015855.dcm
# key 33
# target_key 시작 위치 :5815
# target_key 끝 위치 :5886
# target_key:5854
# target_key_up:5847
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/078/3/1.3.12.2.1107.5.1.4.65211.30000012061121143587500015854.dcm
# key 34
# target_key 시작 위치 :5815
# target_key 끝 위치 :5886
# target_key:5853
# target_key_up:5848
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/078/3/1.3.12.2.1107.5.1.4.65211.30000012061121143587500015853.dcm
# 78번째 data입니다.
# subFolder_list ['ROI_MASK', '9']
# b
# target_mask.keys():[16]
# top , buttom (301, 345) (311, 344)
# left , right (306, 340) (305, 354)
# a
# 이미지를 crop 하고 저장합니다
# key 16
# target_key 시작 위치 :7457
# target_key 끝 위치 :7532
# target_key:7517
# target_key_up:7472
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/079/9/1.3.12.2.1107.5.1.4.65211.30000012091921111318700027517.dcm
# 79번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[37, 38, 39]
# top , buttom (384, 335) (400, 329)
# left , right (392, 326) (387, 341)
# top , buttom (379, 340) (405, 333)
# left , right (392, 326) (384, 347)
# top , buttom (379, 338) (405, 336)
# left , right (386, 326) (386, 348)
# a
# 이미지를 crop 하고 저장합니다
# key 37
# target_key 시작 위치 :179
# target_key 끝 위치 :245
# target_key:209
# target_key_up:215
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/080/3/1.3.12.2.1107.5.1.4.65211.30000012110722022178100030209.dcm
# key 38
# target_key 시작 위치 :179
# target_key 끝 위치 :245
# target_key:208
# target_key_up:216
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/080/3/1.3.12.2.1107.5.1.4.65211.30000012110722022178100030208.dcm
# key 39
# target_key 시작 위치 :179
# target_key 끝 위치 :245
# target_key:207
# target_key_up:217
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/080/3/1.3.12.2.1107.5.1.4.65211.30000012110722022178100030207.dcm
# 80번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[24, 23]
# top , buttom (200, 140) (216, 144)
# left , right (206, 138) (205, 152)
# top , buttom (203, 147) (215, 146)
# left , right (209, 142) (208, 151)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :5524
# target_key 끝 위치 :5583
# target_key:5560
# target_key_up:5547
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/081/4/1.3.12.2.1107.5.1.4.66257.30000013021102264440300005560.dcm
# key 23
# target_key 시작 위치 :5524
# target_key 끝 위치 :5583
# target_key:5561
# target_key_up:5546
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/081/4/1.3.12.2.1107.5.1.4.66257.30000013021102264440300005561.dcm
# 81번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[17, 18, 19]
# top , buttom (303, 348) (319, 354)
# left , right (308, 339) (312, 359)
# top , buttom (297, 356) (318, 347)
# left , right (310, 335) (308, 363)
# top , buttom (298, 355) (317, 350)
# left , right (307, 344) (301, 361)
# a
# 이미지를 crop 하고 저장합니다
# key 17
# target_key 시작 위치 :1560
# target_key 끝 위치 :1633
# target_key:1617
# target_key_up:1576
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/082/4/1.3.12.2.1107.5.1.4.83099.30000016042421305736400031617.dcm
# key 18
# target_key 시작 위치 :1560
# target_key 끝 위치 :1633
# target_key:1616
# target_key_up:1577
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/082/4/1.3.12.2.1107.5.1.4.83099.30000016042421305736400031616.dcm
# key 19
# target_key 시작 위치 :1560
# target_key 끝 위치 :1633
# target_key:1615
# target_key_up:1578
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/082/4/1.3.12.2.1107.5.1.4.83099.30000016042421305736400031615.dcm
# 82번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[43, 44]
# top , buttom (235, 88) (258, 89)
# left , right (249, 78) (242, 97)
# top , buttom (234, 88) (256, 88)
# left , right (243, 81) (244, 97)
# a
# 이미지를 crop 하고 저장합니다
# key 43
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:679
# target_key_up:694
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/083/3/1.3.12.2.1107.5.1.4.50122.30000013060900205596800000679.dcm
# key 44
# target_key 시작 위치 :652
# target_key 끝 위치 :721
# target_key:678
# target_key_up:695
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/083/3/1.3.12.2.1107.5.1.4.50122.30000013060900205596800000678.dcm
# 83번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[42, 43, 44]
# top , buttom (343, 157) (362, 149)
# left , right (350, 141) (357, 169)
# top , buttom (342, 157) (366, 161)
# left , right (351, 143) (356, 170)
# top , buttom (335, 160) (365, 158)
# left , right (352, 147) (349, 168)
# a
# 이미지를 crop 하고 저장합니다
# key 42
# target_key 시작 위치 :4216
# target_key 끝 위치 :4283
# target_key:4242
# target_key_up:4257
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/084/3/1.3.12.2.1107.5.1.4.66417.30000013101322192712900024242.dcm
# key 43
# target_key 시작 위치 :4216
# target_key 끝 위치 :4283
# target_key:4241
# target_key_up:4258
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/084/3/1.3.12.2.1107.5.1.4.66417.30000013101322192712900024241.dcm
# key 44
# target_key 시작 위치 :4216
# target_key 끝 위치 :4283
# target_key:4240
# target_key_up:4259
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/084/3/1.3.12.2.1107.5.1.4.66417.30000013101322192712900024240.dcm
# 84번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[40, 41, 42, 38, 39]
# top , buttom (192, 195) (224, 190)
# left , right (204, 181) (200, 206)
# top , buttom (193, 197) (220, 192)
# left , right (208, 180) (197, 205)
# top , buttom (197, 195) (213, 192)
# left , right (200, 190) (203, 204)
# top , buttom (198, 192) (222, 196)
# left , right (206, 184) (205, 208)
# top , buttom (195, 190) (225, 192)
# left , right (203, 181) (202, 209)
# a
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :9029
# target_key 끝 위치 :9093
# target_key:9054
# target_key_up:9068
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029054.dcm
# key 41
# target_key 시작 위치 :9029
# target_key 끝 위치 :9093
# target_key:9053
# target_key_up:9069
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029053.dcm
# key 42
# target_key 시작 위치 :9029
# target_key 끝 위치 :9093
# target_key:9052
# target_key_up:9070
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029052.dcm
# key 38
# target_key 시작 위치 :9029
# target_key 끝 위치 :9093
# target_key:9056
# target_key_up:9066
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029056.dcm
# key 39
# target_key 시작 위치 :9029
# target_key 끝 위치 :9093
# target_key:9055
# target_key_up:9067
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/085/3/1.3.12.2.1107.5.1.4.66417.30000014042722171601400029055.dcm
# 85번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[24, 25, 26]
# top , buttom (199, 168) (217, 173)
# left , right (205, 164) (203, 178)
# top , buttom (197, 167) (227, 169)
# left , right (206, 160) (204, 179)
# top , buttom (196, 176) (214, 171)
# left , right (208, 163) (204, 181)
# a
# 이미지를 crop 하고 저장합니다
# key 24
# target_key 시작 위치 :5965
# target_key 끝 위치 :6033
# target_key:6010
# target_key_up:5988
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/086/3/1.3.12.2.1107.5.1.4.66417.30000015102521065461500036010.dcm
# key 25
# target_key 시작 위치 :5965
# target_key 끝 위치 :6033
# target_key:6009
# target_key_up:5989
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/086/3/1.3.12.2.1107.5.1.4.66417.30000015102521065461500036009.dcm
# key 26
# target_key 시작 위치 :5965
# target_key 끝 위치 :6033
# target_key:6008
# target_key_up:5990
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/086/3/1.3.12.2.1107.5.1.4.66417.30000015102521065461500036008.dcm
# 86번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[48, 47]
# top , buttom (339, 374) (347, 378)
# left , right (340, 373) (343, 382)
# top , buttom (335, 375) (350, 376)
# left , right (339, 369) (342, 385)
# a
# 이미지를 crop 하고 저장합니다
# key 48
# target_key 시작 위치 :1880
# target_key 끝 위치 :1945
# target_key:1898
# target_key_up:1927
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/087/3/1.3.12.2.1107.5.1.4.66417.30000014102321231623200031898.dcm
# key 47
# target_key 시작 위치 :1880
# target_key 끝 위치 :1945
# target_key:1899
# target_key_up:1926
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/087/3/1.3.12.2.1107.5.1.4.66417.30000014102321231623200031899.dcm
# 87번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[33, 34]
# top , buttom (332, 204) (342, 203)
# left , right (336, 199) (336, 208)
# top , buttom (329, 202) (349, 201)
# left , right (335, 196) (339, 214)
# a
# 이미지를 crop 하고 저장합니다
# key 33
# target_key 시작 위치 :1151
# target_key 끝 위치 :1215
# target_key:1183
# target_key_up:1183
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/088/3/1.3.12.2.1107.5.1.4.83099.30000014102821363771800041183.dcm
# key 34
# target_key 시작 위치 :1151
# target_key 끝 위치 :1215
# target_key:1182
# target_key_up:1184
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/088/3/1.3.12.2.1107.5.1.4.83099.30000014102821363771800041182.dcm
# 88번째 data입니다.
# subFolder_list ['ROI_MASK', '4']
# b
# target_mask.keys():[33, 34]
# top , buttom (335, 394) (352, 394)
# left , right (340, 388) (345, 408)
# top , buttom (332, 390) (350, 392)
# left , right (340, 384) (340, 408)
# a
# 이미지를 crop 하고 저장합니다
# key 33
# target_key 시작 위치 :64
# target_key 끝 위치 :127
# target_key:95
# target_key_up:96
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/089/4/1.3.12.2.1107.5.1.4.51698.30000015010121153334300000095.dcm
# key 34
# target_key 시작 위치 :64
# target_key 끝 위치 :127
# target_key:94
# target_key_up:97
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/089/4/1.3.12.2.1107.5.1.4.51698.30000015010121153334300000094.dcm
# 89번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[32, 33, 34, 35, 31]
# top , buttom (179, 382) (208, 388)
# left , right (192, 371) (188, 396)
# top , buttom (183, 381) (206, 383)
# left , right (190, 370) (191, 396)
# top , buttom (183, 378) (202, 383)
# left , right (188, 375) (188, 400)
# top , buttom (185, 382) (201, 391)
# left , right (190, 378) (192, 394)
# top , buttom (180, 385) (205, 393)
# left , right (189, 374) (187, 396)
# a
# 이미지를 crop 하고 저장합니다
# key 32
# target_key 시작 위치 :5455
# target_key 끝 위치 :5525
# target_key:5494
# target_key_up:5486
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025494.dcm
# key 33
# target_key 시작 위치 :5455
# target_key 끝 위치 :5525
# target_key:5493
# target_key_up:5487
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025493.dcm
# key 34
# target_key 시작 위치 :5455
# target_key 끝 위치 :5525
# target_key:5492
# target_key_up:5488
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025492.dcm
# key 35
# target_key 시작 위치 :5455
# target_key 끝 위치 :5525
# target_key:5491
# target_key_up:5489
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025491.dcm
# key 31
# target_key 시작 위치 :5455
# target_key 끝 위치 :5525
# target_key:5495
# target_key_up:5485
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/090/3/1.3.12.2.1107.5.1.4.65211.30000015053121121220400025495.dcm
# 90번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[26, 27, 28]
# top , buttom (270, 102) (295, 102)
# left , right (279, 87) (289, 111)
# top , buttom (270, 102) (297, 105)
# left , right (283, 84) (286, 112)
# top , buttom (280, 97) (293, 100)
# left , right (282, 94) (285, 106)
# a
# 이미지를 crop 하고 저장합니다
# key 26
# target_key 시작 위치 :3675
# target_key 끝 위치 :3754
# target_key:3729
# target_key_up:3700
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/091/3/1.3.12.2.1107.5.1.4.66417.30000015051721350206700003729.dcm
# key 27
# target_key 시작 위치 :3675
# target_key 끝 위치 :3754
# target_key:3728
# target_key_up:3701
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/091/3/1.3.12.2.1107.5.1.4.66417.30000015051721350206700003728.dcm
# key 28
# target_key 시작 위치 :3675
# target_key 끝 위치 :3754
# target_key:3727
# target_key_up:3702
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/091/3/1.3.12.2.1107.5.1.4.66417.30000015051721350206700003727.dcm
# 91번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[16, 15]
# top , buttom (187, 202) (207, 196)
# left , right (196, 190) (194, 209)
# top , buttom (186, 196) (209, 199)
# left , right (195, 189) (193, 211)
# a
# 이미지를 crop 하고 저장합니다
# key 16
# target_key 시작 위치 :8992
# target_key 끝 위치 :9068
# target_key:9053
# target_key_up:9007
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/092/3/1.3.12.2.1107.5.1.4.51698.30000015091223460512500009053.dcm
# key 15
# target_key 시작 위치 :8992
# target_key 끝 위치 :9068
# target_key:9054
# target_key_up:9006
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/092/3/1.3.12.2.1107.5.1.4.51698.30000015091223460512500009054.dcm
# 92번째 data입니다.
# subFolder_list ['ROI_MASK', '3']
# b
# target_mask.keys():[40, 41, 38, 39]
# top , buttom (305, 207) (331, 209)
# left , right (314, 197) (311, 222)
# top , buttom (305, 206) (332, 212)
# left , right (313, 199) (318, 220)
# top , buttom (304, 210) (335, 213)
# left , right (321, 202) (312, 225)
# top , buttom (302, 208) (335, 213)
# left , right (317, 199) (312, 226)
# a
# 이미지를 crop 하고 저장합니다
# key 40
# target_key 시작 위치 :9143
# target_key 끝 위치 :9213
# target_key:9174
# target_key_up:9182
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009174.dcm
# key 41
# target_key 시작 위치 :9143
# target_key 끝 위치 :9213
# target_key:9173
# target_key_up:9183
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009173.dcm
# key 38
# target_key 시작 위치 :9143
# target_key 끝 위치 :9213
# target_key:9176
# target_key_up:9180
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009176.dcm
# key 39
# target_key 시작 위치 :9143
# target_key 끝 위치 :9213
# target_key:9175
# target_key_up:9181
# target_path /home/seongjung/ASAN_project1/project1/CCM_Data/Benign/093/3/1.3.12.2.1107.5.1.4.66257.30000016032021363731200009175.dcm

# %%
>>> from operator import add
>>> map(add, list1, list2)
[5, 7, 9]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-54fa4c24b58c> in <module>()
#       1 from operator import add
# ----> 2 map(add, list1, list2)
#       3 [5, 7, 9]
#
# NameError: name 'list1' is not defined

# %%
def change_all_name(list_):
    ret_list=[]
    for i,file_name in enumerate(list_):
        ret_list.append(change_file_name(file_name))
    
    return ret_list
def change_file_name(file_name):
    """
    1.3.12.2.1107.5.1.4.51914.30000006121806122618700000702.dcm
    -->30000006121806122618700000702.dcm
    -->name[-2:]=02
    """
    extension=file_name.split('.')[-1]
    name=file_name.split('.')[-2]
    name=name[-2:]
    """
    """
    return name
def make_dict(list_name , list_path):
    ret_dic={}
    for i,ele in enumerate(list_path):
        ret_dic[list_name[i]]=ele
    return ret_dic

# %%
mask_path=crawl_folder('/home/seongjung/ASAN_project1/project1/CCM_Data/Benign/002/ROI_MASK')
mask_name=change_all_name(mask_path)
mask_name_int= map(int, mask_name)
#list__.sort(key=int)
print mask_name_int
mask_dic=make_dict(mask_name_int,mask_path)
